# %%
import re
import os
import shutil
import requests
import polars as pl
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor
import rasterio
import numpy as np

from rasterio.transform import Affine

# %%
def fetch_file_links(year_url: str, file_type: str) -> list[str]:
    """
    Fetches file links from a given URL that match a specific file type and filter by additional criteria.
    
    Parameters:
    - year_url: The base URL to search for file links.
    - file_type: The file extension to filter links by.
    
    Returns:
    A list of URLs that match the specified criteria.
    """
    session = requests.Session()
    try:
        response = session.get(year_url)
        response.raise_for_status()  # Raises a HTTPError if the status is 4xx, 5xx
        soup = BeautifulSoup(response.text, 'html.parser')
        links = soup.find_all('a', href=True)
        file_links = [f"{year_url}{link['href']}" for link in links if link['href'].endswith('.asc')]
        filtered_links = [link for link in file_links if file_type in link]
        return filtered_links
    except requests.exceptions.HTTPError as http_err:
        print(f"HTTP error occurred: {http_err}")
    except requests.exceptions.RequestException as err:
        print(f"Request error occurred: {err}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    return []

# %%
def download_file(url, destination_folder):
    filename = url.split("/")[-1]
    destination_path = os.path.join(destination_folder, filename)
    try:
        response = requests.get(url)
        response.raise_for_status()
        with open(destination_path, 'wb') as f:
            f.write(response.content)
        print(f"File downloaded successfully: {filename}")
    except requests.exceptions.RequestException as e:
        print(f"Failed to download the file: {filename}. Error: {e}")

# %%
def append_and_process_files(source_dir, transform, row_start, row_end, col_start, col_end):
    master_df = pl.DataFrame()
    for filename in os.listdir(source_dir):
        if filename.endswith('.asc'):
            file_path = os.path.join(source_dir, filename)
            with rasterio.open(file_path) as src:
                data = src.read(1)  # Read the first band
                filtered_data = data[row_start:row_end, col_start:col_end]
            df = create_polars_dataframe(file_path, filtered_data, row_start, row_end, col_start, col_end, transform)
            master_df = master_df.vstack(df) if not master_df.is_empty() else df
    return master_df

# %%
def create_polars_dataframe(file_name: str, data: np.ndarray, row_start: int, row_end: int, col_start: int, col_end: int, transform: Affine):
    """
    Creates a Polars DataFrame from filtered raster data with columns for time, latitude, longitude, and EDDI values.

    Parameters:
    - file_name (str): The name of the file, used to extract the time information.
    - data (numpy.ndarray): The filtered raster data array.
    - row_start (int): The starting index for rows of the filtered data.
    - row_end (int): The ending index for rows of the filtered data.
    - col_start (int): The starting index for columns of the filtered data.
    - col_end (int): The ending index for columns of the filtered data.
    - transform (Affine): The affine transformation used to convert indices to geographic coordinates.

    Returns:
    - pl.DataFrame: A Polars DataFrame with columns for time, latitude, longitude, and EDDI values.
    """
    # Extract the date from the file name using regular expressions
    date_match = re.search(r'\d{8}', file_name)
    if date_match:
        date = date_match.group(0)
        # Transform the date to 'yyyy-mm-dd' format
        formatted_date = f"{date[:4]}-{date[4:6]}-{date[6:]}"
    else:
        raise ValueError("Date not found in file name.")

    # Generate latitude and longitude arrays
    lon_arr = []
    lat_arr = []
    for row in range(row_start, row_end):
        for col in range(col_start, col_end):
            lon, lat = transform * (col, row)
            lon_arr.append(lon)
            lat_arr.append(lat)

    # Flatten the data array to match the latitude and longitude arrays
    eddi_values = data.flatten()

    # Create a Polars DataFrame
    df = pl.DataFrame({
        "time": [formatted_date] * len(eddi_values),
        "lat": lat_arr,
        "lon": lon_arr,
        "eddi": eddi_values
    })

    return df

# %%
def geographic_to_index(lon, lat, transform):
    """
    Convert geographic coordinates to raster indices.

    Parameters:
    - lon (float): The longitude to convert.
    - lat (float): The latitude to convert.
    - transform (Affine): The affine transform associated with the raster, defining how geographic coordinates are transformed into raster indices.

    Returns:
    - (int, int): The zero-based column index and row index corresponding to the given longitude and latitude.
    """
    col, row = ~transform * (lon, lat)
    return int(col), int(row)

# %%
# Main function for dowloading data 
def download_and_process_raster_data(base_url, start_year, end_year, file_type, destination_folder):
    # Define the affine transform for a raster where each pixel represents a 0.5x0.5 degree area
    transform = Affine(0.5, 0.0, -180, 0.0, -0.5, 90)

    # Define geographic bounds and calculate index ranges
    lat_range = (-12, 22)  # South to North
    lon_range = (23, 52)  # West to East
    col_start, row_end = geographic_to_index(lon_range[0], lat_range[0], transform)
    col_end, row_start = geographic_to_index(lon_range[1], lat_range[1], transform)

    for year in range(start_year, end_year + 1):
        year_url = f"{base_url}{year}/"
        year_destination_folder = os.path.join(destination_folder, str(year))
        
        if not os.path.exists(year_destination_folder):
            os.makedirs(year_destination_folder)
        
        file_links = fetch_file_links(year_url, file_type)
        with ThreadPoolExecutor(max_workers=8) as executor:
            executor.map(lambda url: download_file(url, year_destination_folder), file_links)
        
        # Process and append raster data to a Polars DataFrame
        master_df = append_and_process_files(year_destination_folder, transform, row_start, row_end, col_start, col_end)
        
        # Save the DataFrame as a Parquet file
        parquet_path = os.path.join(destination_folder, f"EDDI_{file_type}_{year}.parquet")
        master_df.write_parquet(parquet_path)
        print(f"Data for year {year} processed and saved as Parquet at {parquet_path}.")
        
        shutil.rmtree(year_destination_folder)  # Optional: remove the directory after processing

# %%
def merge_parquet_files(directory_path: str, output_file_path: str) -> None:
    """
    Merges multiple Parquet files located in a specified directory into a single Parquet file.

    Args:
    directory_path (str): The path to the directory containing the Parquet files.
    output_file_path (str): The path where the merged Parquet file will be saved.

    Returns:
    None
    """

    # List all Parquet files in the directory
    parquet_files = [file for file in os.listdir(directory_path) if file.endswith('.parquet')]

    # Read each Parquet file into a DataFrame and store in a list
    dataframes = [pl.read_parquet(os.path.join(directory_path, file)) for file in parquet_files]

    # Concatenate all DataFrames vertically
    merged_df = pl.concat(dataframes)

    # Write the merged DataFrame to a new Parquet file
    merged_df.write_parquet(output_file_path)

    print(f"Merged file saved to {output_file_path}")

# %%
import shutil
import os

def delete_directory(dir_path: str) -> None:
    """
    Deletes a directory and all of its contents.
    
    Args:
    dir_path (str): The path to the directory to be deleted.
    
    Raises:
    FileNotFoundError: If the directory does not exist.
    PermissionError: If the deletion is not allowed due to permission restrictions.
    """
    if os.path.exists(dir_path):
        shutil.rmtree(dir_path)
        print(f"Directory '{dir_path}' has been deleted.")
    else:
        raise FileNotFoundError(f"The directory {dir_path} does not exist.")

# Specify the directory to delete
# directory_path = "/workspace/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/eddi"

# Delete the directory
# try:
#     delete_directory(directory_path)
# except Exception as e:
#     print(f"An error occurred: {e}")

# %%
    base_url = "https://downloads.psl.noaa.gov/Projects/EDDI/global_archive/NCEP/"
    destination_folder = "/teamspace/studios/this_studio/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/eddi"
    start_year = 1981
    end_year = 2024
    file_types = ["01wk", "02wk", "01mn", "02mn", "03mn", "06mn", "09mn", "12mn"]

    for file_type in file_types:
        download_and_process_raster_data(base_url, start_year, end_year, file_type, destination_folder)

        # Construct the directory and output file paths
        directory_path = '/teamspace/studios/this_studio/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/eddi'
        output_file_path = f'/teamspace/studios/this_studio/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/merged_eddi_data_{file_type}.parquet'

        # Call the function to merge the files
        merge_parquet_files(directory_path, output_file_path)

        # Delete the directory
        try:
            delete_directory(directory_path)
        except Exception as e:
            print(f"An error occurred: {e}")
# Out:
# File downloaded successfully: EDDI_01wk_19810101.asc
# File downloaded successfully: EDDI_01wk_19810105.asc
# File downloaded successfully: EDDI_01wk_19810108.asc
# File downloaded successfully: EDDI_01wk_19810107.asc
# File downloaded successfully: EDDI_01wk_19810106.asc
# File downloaded successfully: EDDI_01wk_19810102.asc
# File downloaded successfully: EDDI_01wk_19810104.asc
# File downloaded successfully: EDDI_01wk_19810103.asc
# File downloaded successfully: EDDI_01wk_19810109.asc
# File downloaded successfully: EDDI_01wk_19810111.asc
# File downloaded successfully: EDDI_01wk_19810113.asc
# File downloaded successfully: EDDI_01wk_19810116.asc
# File downloaded successfully: EDDI_01wk_19810114.asc
# File downloaded successfully: EDDI_01wk_19810112.asc
# File downloaded successfully: EDDI_01wk_19810110.asc
# File downloaded successfully: EDDI_01wk_19810117.asc
# File downloaded successfully: EDDI_01wk_19810120.asc
# File downloaded successfully: EDDI_01wk_19810119.asc
# File downloaded successfully: EDDI_01wk_19810121.asc
# File downloaded successfully: EDDI_01wk_19810123.asc
# File downloaded successfully: EDDI_01wk_19810122.asc
# File downloaded successfully: EDDI_01wk_19810124.asc
# File downloaded successfully: EDDI_01wk_19810125.asc
# File downloaded successfully: EDDI_01wk_19810127.asc
# File downloaded successfully: EDDI_01wk_19810128.asc
# File downloaded successfully: EDDI_01wk_19810126.asc
# File downloaded successfully: EDDI_01wk_19810129.asc
# File downloaded successfully: EDDI_01wk_19810130.asc
# File downloaded successfully: EDDI_01wk_19810131.asc
# File downloaded successfully: EDDI_01wk_19810203.asc
# File downloaded successfully: EDDI_01wk_19810201.asc
# File downloaded successfully: EDDI_01wk_19810202.asc
# File downloaded successfully: EDDI_01wk_19810205.asc
# File downloaded successfully: EDDI_01wk_19810204.asc
# File downloaded successfully: EDDI_01wk_19810206.asc
# File downloaded successfully: EDDI_01wk_19810207.asc
# File downloaded successfully: EDDI_01wk_19810209.asc
# File downloaded successfully: EDDI_01wk_19810208.asc
# File downloaded successfully: EDDI_01wk_19810210.asc
# File downloaded successfully: EDDI_01wk_19810211.asc
# File downloaded successfully: EDDI_01wk_19810212.asc
# File downloaded successfully: EDDI_01wk_19810213.asc
# File downloaded successfully: EDDI_01wk_19810215.asc
# File downloaded successfully: EDDI_01wk_19810214.asc
# File downloaded successfully: EDDI_01wk_19810115.asc
# File downloaded successfully: EDDI_01wk_19810219.asc
# File downloaded successfully: EDDI_01wk_19810220.asc
# File downloaded successfully: EDDI_01wk_19810216.asc
# File downloaded successfully: EDDI_01wk_19810217.asc
# File downloaded successfully: EDDI_01wk_19810218.asc
# File downloaded successfully: EDDI_01wk_19810221.asc
# File downloaded successfully: EDDI_01wk_19810222.asc
# File downloaded successfully: EDDI_01wk_19810118.asc
# File downloaded successfully: EDDI_01wk_19810226.asc
# File downloaded successfully: EDDI_01wk_19810225.asc
# File downloaded successfully: EDDI_01wk_19810227.asc
# File downloaded successfully: EDDI_01wk_19810228.asc
# File downloaded successfully: EDDI_01wk_19810301.asc
# File downloaded successfully: EDDI_01wk_19810302.asc
# File downloaded successfully: EDDI_01wk_19810303.asc
# File downloaded successfully: EDDI_01wk_19810304.asc
# File downloaded successfully: EDDI_01wk_19810305.asc
# File downloaded successfully: EDDI_01wk_19810307.asc
# File downloaded successfully: EDDI_01wk_19810306.asc
# File downloaded successfully: EDDI_01wk_19810308.asc
# File downloaded successfully: EDDI_01wk_19810309.asc
# File downloaded successfully: EDDI_01wk_19810310.asc
# File downloaded successfully: EDDI_01wk_19810311.asc
# File downloaded successfully: EDDI_01wk_19810224.asc
# File downloaded successfully: EDDI_01wk_19810312.asc
# File downloaded successfully: EDDI_01wk_19810314.asc
# File downloaded successfully: EDDI_01wk_19810313.asc
# File downloaded successfully: EDDI_01wk_19810316.asc
# File downloaded successfully: EDDI_01wk_19810315.asc
# File downloaded successfully: EDDI_01wk_19810318.asc
# File downloaded successfully: EDDI_01wk_19810319.asc
# File downloaded successfully: EDDI_01wk_19810317.asc
# File downloaded successfully: EDDI_01wk_19810320.asc
# File downloaded successfully: EDDI_01wk_19810321.asc
# File downloaded successfully: EDDI_01wk_19810322.asc
# File downloaded successfully: EDDI_01wk_19810323.asc
# File downloaded successfully: EDDI_01wk_19810324.asc
# File downloaded successfully: EDDI_01wk_19810326.asc
# File downloaded successfully: EDDI_01wk_19810325.asc
# File downloaded successfully: EDDI_01wk_19810327.asc
# File downloaded successfully: EDDI_01wk_19810329.asc
# File downloaded successfully: EDDI_01wk_19810223.asc
# File downloaded successfully: EDDI_01wk_19810330.asc
# File downloaded successfully: EDDI_01wk_19810403.asc
# File downloaded successfully: EDDI_01wk_19810401.asc
# File downloaded successfully: EDDI_01wk_19810331.asc
# File downloaded successfully: EDDI_01wk_19810402.asc
# File downloaded successfully: EDDI_01wk_19810404.asc
# File downloaded successfully: EDDI_01wk_19810405.asc
# File downloaded successfully: EDDI_01wk_19810408.asc
# File downloaded successfully: EDDI_01wk_19810407.asc
# File downloaded successfully: EDDI_01wk_19810410.asc
# File downloaded successfully: EDDI_01wk_19810411.asc
# File downloaded successfully: EDDI_01wk_19810409.asc
# File downloaded successfully: EDDI_01wk_19810412.asc
# File downloaded successfully: EDDI_01wk_19810413.asc
# File downloaded successfully: EDDI_01wk_19810415.asc
# File downloaded successfully: EDDI_01wk_19810417.asc
# File downloaded successfully: EDDI_01wk_19810414.asc
# File downloaded successfully: EDDI_01wk_19810418.asc
# File downloaded successfully: EDDI_01wk_19810416.asc
# File downloaded successfully: EDDI_01wk_19810406.asc
# File downloaded successfully: EDDI_01wk_19810419.asc
# File downloaded successfully: EDDI_01wk_19810421.asc
# File downloaded successfully: EDDI_01wk_19810420.asc
# File downloaded successfully: EDDI_01wk_19810424.asc
# File downloaded successfully: EDDI_01wk_19810422.asc
# File downloaded successfully: EDDI_01wk_19810423.asc
# File downloaded successfully: EDDI_01wk_19810425.asc
# File downloaded successfully: EDDI_01wk_19810427.asc
# File downloaded successfully: EDDI_01wk_19810428.asc
# File downloaded successfully: EDDI_01wk_19810328.asc
# File downloaded successfully: EDDI_01wk_19810501.asc
# File downloaded successfully: EDDI_01wk_19810426.asc
# File downloaded successfully: EDDI_01wk_19810503.asc
# File downloaded successfully: EDDI_01wk_19810429.asc
# File downloaded successfully: EDDI_01wk_19810502.asc
# File downloaded successfully: EDDI_01wk_19810505.asc
# File downloaded successfully: EDDI_01wk_19810504.asc
# File downloaded successfully: EDDI_01wk_19810506.asc
# File downloaded successfully: EDDI_01wk_19810509.asc
# File downloaded successfully: EDDI_01wk_19810511.asc
# File downloaded successfully: EDDI_01wk_19810510.asc
# File downloaded successfully: EDDI_01wk_19810508.asc
# File downloaded successfully: EDDI_01wk_19810514.asc
# File downloaded successfully: EDDI_01wk_19810512.asc
# File downloaded successfully: EDDI_01wk_19810513.asc
# File downloaded successfully: EDDI_01wk_19810515.asc
# File downloaded successfully: EDDI_01wk_19810516.asc
# File downloaded successfully: EDDI_01wk_19810518.asc
# File downloaded successfully: EDDI_01wk_19810507.asc
# File downloaded successfully: EDDI_01wk_19810520.asc
# File downloaded successfully: EDDI_01wk_19810521.asc
# File downloaded successfully: EDDI_01wk_19810519.asc
# File downloaded successfully: EDDI_01wk_19810517.asc
# File downloaded successfully: EDDI_01wk_19810522.asc
# File downloaded successfully: EDDI_01wk_19810524.asc
# File downloaded successfully: EDDI_01wk_19810527.asc
# File downloaded successfully: EDDI_01wk_19810523.asc
# File downloaded successfully: EDDI_01wk_19810525.asc
# File downloaded successfully: EDDI_01wk_19810528.asc
# File downloaded successfully: EDDI_01wk_19810601.asc
# File downloaded successfully: EDDI_01wk_19810530.asc
# File downloaded successfully: EDDI_01wk_19810430.asc
# File downloaded successfully: EDDI_01wk_19810529.asc
# File downloaded successfully: EDDI_01wk_19810531.asc
# File downloaded successfully: EDDI_01wk_19810604.asc
# File downloaded successfully: EDDI_01wk_19810603.asc
# File downloaded successfully: EDDI_01wk_19810605.asc
# File downloaded successfully: EDDI_01wk_19810526.asc
# File downloaded successfully: EDDI_01wk_19810608.asc
# File downloaded successfully: EDDI_01wk_19810610.asc
# File downloaded successfully: EDDI_01wk_19810609.asc
# File downloaded successfully: EDDI_01wk_19810613.asc
# File downloaded successfully: EDDI_01wk_19810611.asc
# File downloaded successfully: EDDI_01wk_19810612.asc
# File downloaded successfully: EDDI_01wk_19810614.asc
# File downloaded successfully: EDDI_01wk_19810606.asc
# File downloaded successfully: EDDI_01wk_19810615.asc
# File downloaded successfully: EDDI_01wk_19810618.asc
# File downloaded successfully: EDDI_01wk_19810617.asc
# File downloaded successfully: EDDI_01wk_19810616.asc
# File downloaded successfully: EDDI_01wk_19810620.asc
# File downloaded successfully: EDDI_01wk_19810619.asc
# File downloaded successfully: EDDI_01wk_19810621.asc
# File downloaded successfully: EDDI_01wk_19810622.asc
# File downloaded successfully: EDDI_01wk_19810624.asc
# File downloaded successfully: EDDI_01wk_19810627.asc
# File downloaded successfully: EDDI_01wk_19810625.asc
# File downloaded successfully: EDDI_01wk_19810626.asc
# File downloaded successfully: EDDI_01wk_19810629.asc
# File downloaded successfully: EDDI_01wk_19810623.asc
# File downloaded successfully: EDDI_01wk_19810628.asc
# File downloaded successfully: EDDI_01wk_19810602.asc
# File downloaded successfully: EDDI_01wk_19810630.asc
# File downloaded successfully: EDDI_01wk_19810702.asc
# File downloaded successfully: EDDI_01wk_19810701.asc
# File downloaded successfully: EDDI_01wk_19810607.asc
# File downloaded successfully: EDDI_01wk_19810705.asc
# File downloaded successfully: EDDI_01wk_19810703.asc
# File downloaded successfully: EDDI_01wk_19810707.asc
# File downloaded successfully: EDDI_01wk_19810708.asc
# File downloaded successfully: EDDI_01wk_19810709.asc
# File downloaded successfully: EDDI_01wk_19810704.asc
# File downloaded successfully: EDDI_01wk_19810711.asc
# File downloaded successfully: EDDI_01wk_19810713.asc
# File downloaded successfully: EDDI_01wk_19810712.asc
# File downloaded successfully: EDDI_01wk_19810715.asc
# File downloaded successfully: EDDI_01wk_19810714.asc
# File downloaded successfully: EDDI_01wk_19810716.asc
# File downloaded successfully: EDDI_01wk_19810718.asc
# File downloaded successfully: EDDI_01wk_19810719.asc
# File downloaded successfully: EDDI_01wk_19810706.asc
# File downloaded successfully: EDDI_01wk_19810721.asc
# File downloaded successfully: EDDI_01wk_19810717.asc
# File downloaded successfully: EDDI_01wk_19810720.asc
# File downloaded successfully: EDDI_01wk_19810710.asc
# File downloaded successfully: EDDI_01wk_19810723.asc
# File downloaded successfully: EDDI_01wk_19810722.asc
# File downloaded successfully: EDDI_01wk_19810725.asc
# File downloaded successfully: EDDI_01wk_19810728.asc
# File downloaded successfully: EDDI_01wk_19810731.asc
# File downloaded successfully: EDDI_01wk_19810730.asc
# File downloaded successfully: EDDI_01wk_19810724.asc
# File downloaded successfully: EDDI_01wk_19810727.asc
# File downloaded successfully: EDDI_01wk_19810726.asc
# File downloaded successfully: EDDI_01wk_19810802.asc
# File downloaded successfully: EDDI_01wk_19810803.asc
# File downloaded successfully: EDDI_01wk_19810729.asc
# File downloaded successfully: EDDI_01wk_19810801.asc
# File downloaded successfully: EDDI_01wk_19810805.asc
# File downloaded successfully: EDDI_01wk_19810806.asc
# File downloaded successfully: EDDI_01wk_19810809.asc
# File downloaded successfully: EDDI_01wk_19810808.asc
# File downloaded successfully: EDDI_01wk_19810804.asc
# File downloaded successfully: EDDI_01wk_19810812.asc
# File downloaded successfully: EDDI_01wk_19810807.asc
# File downloaded successfully: EDDI_01wk_19810811.asc
# File downloaded successfully: EDDI_01wk_19810815.asc
# File downloaded successfully: EDDI_01wk_19810810.asc
# File downloaded successfully: EDDI_01wk_19810814.asc
# File downloaded successfully: EDDI_01wk_19810813.asc
# File downloaded successfully: EDDI_01wk_19810818.asc
# File downloaded successfully: EDDI_01wk_19810817.asc
# File downloaded successfully: EDDI_01wk_19810816.asc
# File downloaded successfully: EDDI_01wk_19810820.asc
# File downloaded successfully: EDDI_01wk_19810819.asc
# File downloaded successfully: EDDI_01wk_19810822.asc
# File downloaded successfully: EDDI_01wk_19810823.asc
# File downloaded successfully: EDDI_01wk_19810825.asc
# File downloaded successfully: EDDI_01wk_19810821.asc
# File downloaded successfully: EDDI_01wk_19810824.asc
# File downloaded successfully: EDDI_01wk_19810827.asc
# File downloaded successfully: EDDI_01wk_19810828.asc
# File downloaded successfully: EDDI_01wk_19810826.asc
# File downloaded successfully: EDDI_01wk_19810902.asc
# File downloaded successfully: EDDI_01wk_19810830.asc
# File downloaded successfully: EDDI_01wk_19810831.asc
# File downloaded successfully: EDDI_01wk_19810829.asc
# File downloaded successfully: EDDI_01wk_19810901.asc
# File downloaded successfully: EDDI_01wk_19810905.asc
# File downloaded successfully: EDDI_01wk_19810903.asc
# File downloaded successfully: EDDI_01wk_19810904.asc
# File downloaded successfully: EDDI_01wk_19810908.asc
# File downloaded successfully: EDDI_01wk_19810906.asc
# File downloaded successfully: EDDI_01wk_19810909.asc
# File downloaded successfully: EDDI_01wk_19810914.asc
# File downloaded successfully: EDDI_01wk_19810911.asc
# File downloaded successfully: EDDI_01wk_19810910.asc
# File downloaded successfully: EDDI_01wk_19810912.asc
# File downloaded successfully: EDDI_01wk_19810916.asc
# File downloaded successfully: EDDI_01wk_19810915.asc
# File downloaded successfully: EDDI_01wk_19810917.asc
# File downloaded successfully: EDDI_01wk_19810920.asc
# File downloaded successfully: EDDI_01wk_19810919.asc
# File downloaded successfully: EDDI_01wk_19810918.asc
# File downloaded successfully: EDDI_01wk_19810923.asc
# File downloaded successfully: EDDI_01wk_19810922.asc
# File downloaded successfully: EDDI_01wk_19810921.asc
# File downloaded successfully: EDDI_01wk_19810926.asc
# File downloaded successfully: EDDI_01wk_19810925.asc
# File downloaded successfully: EDDI_01wk_19810924.asc
# File downloaded successfully: EDDI_01wk_19810929.asc
# File downloaded successfully: EDDI_01wk_19810928.asc
# File downloaded successfully: EDDI_01wk_19810927.asc
# File downloaded successfully: EDDI_01wk_19810907.asc
# File downloaded successfully: EDDI_01wk_19811001.asc
# File downloaded successfully: EDDI_01wk_19810930.asc
# File downloaded successfully: EDDI_01wk_19811002.asc
# File downloaded successfully: EDDI_01wk_19811003.asc
# File downloaded successfully: EDDI_01wk_19810913.asc
# File downloaded successfully: EDDI_01wk_19811005.asc
# File downloaded successfully: EDDI_01wk_19811004.asc
# File downloaded successfully: EDDI_01wk_19811007.asc
# File downloaded successfully: EDDI_01wk_19811006.asc
# File downloaded successfully: EDDI_01wk_19811010.asc
# File downloaded successfully: EDDI_01wk_19811008.asc
# File downloaded successfully: EDDI_01wk_19811009.asc
# File downloaded successfully: EDDI_01wk_19811012.asc
# File downloaded successfully: EDDI_01wk_19811013.asc
# File downloaded successfully: EDDI_01wk_19811014.asc
# File downloaded successfully: EDDI_01wk_19811017.asc
# File downloaded successfully: EDDI_01wk_19811015.asc
# File downloaded successfully: EDDI_01wk_19811016.asc
# File downloaded successfully: EDDI_01wk_19811018.asc
# File downloaded successfully: EDDI_01wk_19811019.asc
# File downloaded successfully: EDDI_01wk_19811021.asc
# File downloaded successfully: EDDI_01wk_19811020.asc
# File downloaded successfully: EDDI_01wk_19811022.asc
# File downloaded successfully: EDDI_01wk_19811011.asc
# File downloaded successfully: EDDI_01wk_19811023.asc
# File downloaded successfully: EDDI_01wk_19811024.asc
# File downloaded successfully: EDDI_01wk_19811026.asc
# File downloaded successfully: EDDI_01wk_19811025.asc
# File downloaded successfully: EDDI_01wk_19811027.asc
# File downloaded successfully: EDDI_01wk_19811030.asc
# File downloaded successfully: EDDI_01wk_19811028.asc
# File downloaded successfully: EDDI_01wk_19811029.asc
# File downloaded successfully: EDDI_01wk_19811101.asc
# File downloaded successfully: EDDI_01wk_19811102.asc
# File downloaded successfully: EDDI_01wk_19811031.asc
# File downloaded successfully: EDDI_01wk_19811103.asc
# File downloaded successfully: EDDI_01wk_19811104.asc
# File downloaded successfully: EDDI_01wk_19811105.asc
# File downloaded successfully: EDDI_01wk_19811106.asc
# File downloaded successfully: EDDI_01wk_19811108.asc
# File downloaded successfully: EDDI_01wk_19811107.asc
# File downloaded successfully: EDDI_01wk_19811113.asc
# File downloaded successfully: EDDI_01wk_19811110.asc
# File downloaded successfully: EDDI_01wk_19811109.asc
# File downloaded successfully: EDDI_01wk_19811111.asc
# File downloaded successfully: EDDI_01wk_19811114.asc
# File downloaded successfully: EDDI_01wk_19811112.asc
# File downloaded successfully: EDDI_01wk_19811115.asc
# File downloaded successfully: EDDI_01wk_19811118.asc
# File downloaded successfully: EDDI_01wk_19811116.asc
# File downloaded successfully: EDDI_01wk_19811117.asc
# File downloaded successfully: EDDI_01wk_19811119.asc
# File downloaded successfully: EDDI_01wk_19811121.asc
# File downloaded successfully: EDDI_01wk_19811120.asc
# File downloaded successfully: EDDI_01wk_19811122.asc
# File downloaded successfully: EDDI_01wk_19811125.asc
# File downloaded successfully: EDDI_01wk_19811123.asc
# File downloaded successfully: EDDI_01wk_19811126.asc
# File downloaded successfully: EDDI_01wk_19811128.asc
# File downloaded successfully: EDDI_01wk_19811127.asc
# File downloaded successfully: EDDI_01wk_19811129.asc
# File downloaded successfully: EDDI_01wk_19811201.asc
# File downloaded successfully: EDDI_01wk_19811130.asc
# File downloaded successfully: EDDI_01wk_19811203.asc
# File downloaded successfully: EDDI_01wk_19811202.asc
# File downloaded successfully: EDDI_01wk_19811204.asc
# File downloaded successfully: EDDI_01wk_19811205.asc
# File downloaded successfully: EDDI_01wk_19811206.asc
# File downloaded successfully: EDDI_01wk_19811208.asc
# File downloaded successfully: EDDI_01wk_19811209.asc
# File downloaded successfully: EDDI_01wk_19811213.asc
# File downloaded successfully: EDDI_01wk_19811212.asc
# File downloaded successfully: EDDI_01wk_19811214.asc
# File downloaded successfully: EDDI_01wk_19811215.asc
# File downloaded successfully: EDDI_01wk_19811216.asc
# File downloaded successfully: EDDI_01wk_19811217.asc
# File downloaded successfully: EDDI_01wk_19811124.asc
# File downloaded successfully: EDDI_01wk_19811218.asc
# File downloaded successfully: EDDI_01wk_19811219.asc
# File downloaded successfully: EDDI_01wk_19811220.asc
# File downloaded successfully: EDDI_01wk_19811221.asc
# File downloaded successfully: EDDI_01wk_19811223.asc
# File downloaded successfully: EDDI_01wk_19811224.asc
# File downloaded successfully: EDDI_01wk_19811226.asc
# File downloaded successfully: EDDI_01wk_19811207.asc
# File downloaded successfully: EDDI_01wk_19811222.asc
# File downloaded successfully: EDDI_01wk_19811210.asc
# File downloaded successfully: EDDI_01wk_19811227.asc
# File downloaded successfully: EDDI_01wk_19811211.asc
# File downloaded successfully: EDDI_01wk_19811228.asc
# File downloaded successfully: EDDI_01wk_19811230.asc
# File downloaded successfully: EDDI_01wk_19811229.asc
# File downloaded successfully: EDDI_01wk_19811231.asc
# File downloaded successfully: EDDI_01wk_19811225.asc
# Data for year 1981 processed and saved as Parquet at /teamspace/studios/this_studio/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/eddi/EDDI_01wk_1981.parquet.
# File downloaded successfully: EDDI_01wk_19820102.asc
# File downloaded successfully: EDDI_01wk_19820104.asc
# File downloaded successfully: EDDI_01wk_19820106.asc
# File downloaded successfully: EDDI_01wk_19820107.asc
# File downloaded successfully: EDDI_01wk_19820103.asc
# File downloaded successfully: EDDI_01wk_19820110.asc
# File downloaded successfully: EDDI_01wk_19820112.asc
# File downloaded successfully: EDDI_01wk_19820101.asc
# File downloaded successfully: EDDI_01wk_19820105.asc
# File downloaded successfully: EDDI_01wk_19820114.asc
# File downloaded successfully: EDDI_01wk_19820109.asc
# File downloaded successfully: EDDI_01wk_19820111.asc
# File downloaded successfully: EDDI_01wk_19820117.asc
# File downloaded successfully: EDDI_01wk_19820115.asc
# File downloaded successfully: EDDI_01wk_19820116.asc
# File downloaded successfully: EDDI_01wk_19820113.asc
# File downloaded successfully: EDDI_01wk_19820118.asc
# File downloaded successfully: EDDI_01wk_19820120.asc
# File downloaded successfully: EDDI_01wk_19820121.asc
# File downloaded successfully: EDDI_01wk_19820122.asc
# File downloaded successfully: EDDI_01wk_19820119.asc
# File downloaded successfully: EDDI_01wk_19820108.asc
# File downloaded successfully: EDDI_01wk_19820125.asc
# File downloaded successfully: EDDI_01wk_19820123.asc
# File downloaded successfully: EDDI_01wk_19820124.asc
# File downloaded successfully: EDDI_01wk_19820126.asc
# File downloaded successfully: EDDI_01wk_19820127.asc
# File downloaded successfully: EDDI_01wk_19820129.asc
# File downloaded successfully: EDDI_01wk_19820128.asc
# File downloaded successfully: EDDI_01wk_19820131.asc
# File downloaded successfully: EDDI_01wk_19820201.asc
# File downloaded successfully: EDDI_01wk_19820202.asc
# File downloaded successfully: EDDI_01wk_19820203.asc
# File downloaded successfully: EDDI_01wk_19820204.asc
# File downloaded successfully: EDDI_01wk_19820205.asc
# File downloaded successfully: EDDI_01wk_19820130.asc
# File downloaded successfully: EDDI_01wk_19820207.asc
# File downloaded successfully: EDDI_01wk_19820208.asc
# File downloaded successfully: EDDI_01wk_19820206.asc
# File downloaded successfully: EDDI_01wk_19820209.asc
# File downloaded successfully: EDDI_01wk_19820210.asc
# File downloaded successfully: EDDI_01wk_19820211.asc
# File downloaded successfully: EDDI_01wk_19820212.asc
# File downloaded successfully: EDDI_01wk_19820214.asc
# File downloaded successfully: EDDI_01wk_19820215.asc
# File downloaded successfully: EDDI_01wk_19820213.asc
# File downloaded successfully: EDDI_01wk_19820216.asc
# File downloaded successfully: EDDI_01wk_19820217.asc
# File downloaded successfully: EDDI_01wk_19820218.asc
# File downloaded successfully: EDDI_01wk_19820219.asc
# File downloaded successfully: EDDI_01wk_19820220.asc
# File downloaded successfully: EDDI_01wk_19820222.asc
# File downloaded successfully: EDDI_01wk_19820221.asc
# File downloaded successfully: EDDI_01wk_19820224.asc
# File downloaded successfully: EDDI_01wk_19820225.asc
# File downloaded successfully: EDDI_01wk_19820226.asc
# File downloaded successfully: EDDI_01wk_19820227.asc
# File downloaded successfully: EDDI_01wk_19820223.asc
# File downloaded successfully: EDDI_01wk_19820228.asc
# File downloaded successfully: EDDI_01wk_19820301.asc
# File downloaded successfully: EDDI_01wk_19820302.asc
# File downloaded successfully: EDDI_01wk_19820303.asc
# File downloaded successfully: EDDI_01wk_19820304.asc
# File downloaded successfully: EDDI_01wk_19820306.asc
# File downloaded successfully: EDDI_01wk_19820305.asc
# File downloaded successfully: EDDI_01wk_19820307.asc
# File downloaded successfully: EDDI_01wk_19820309.asc
# File downloaded successfully: EDDI_01wk_19820308.asc
# File downloaded successfully: EDDI_01wk_19820310.asc
# File downloaded successfully: EDDI_01wk_19820311.asc
# File downloaded successfully: EDDI_01wk_19820314.asc
# File downloaded successfully: EDDI_01wk_19820313.asc
# File downloaded successfully: EDDI_01wk_19820312.asc
# File downloaded successfully: EDDI_01wk_19820316.asc
# File downloaded successfully: EDDI_01wk_19820317.asc
# File downloaded successfully: EDDI_01wk_19820318.asc
# File downloaded successfully: EDDI_01wk_19820315.asc
# File downloaded successfully: EDDI_01wk_19820319.asc
# File downloaded successfully: EDDI_01wk_19820320.asc
# File downloaded successfully: EDDI_01wk_19820322.asc
# File downloaded successfully: EDDI_01wk_19820321.asc
# File downloaded successfully: EDDI_01wk_19820323.asc
# File downloaded successfully: EDDI_01wk_19820324.asc
# File downloaded successfully: EDDI_01wk_19820325.asc
# File downloaded successfully: EDDI_01wk_19820326.asc
# File downloaded successfully: EDDI_01wk_19820328.asc
# File downloaded successfully: EDDI_01wk_19820329.asc
# File downloaded successfully: EDDI_01wk_19820327.asc
# File downloaded successfully: EDDI_01wk_19820330.asc
# File downloaded successfully: EDDI_01wk_19820401.asc
# File downloaded successfully: EDDI_01wk_19820331.asc
# File downloaded successfully: EDDI_01wk_19820403.asc
# File downloaded successfully: EDDI_01wk_19820404.asc
# File downloaded successfully: EDDI_01wk_19820405.asc
# File downloaded successfully: EDDI_01wk_19820406.asc
# File downloaded successfully: EDDI_01wk_19820402.asc
# File downloaded successfully: EDDI_01wk_19820407.asc
# File downloaded successfully: EDDI_01wk_19820408.asc
# File downloaded successfully: EDDI_01wk_19820409.asc
# File downloaded successfully: EDDI_01wk_19820412.asc
# File downloaded successfully: EDDI_01wk_19820413.asc
# File downloaded successfully: EDDI_01wk_19820411.asc
# File downloaded successfully: EDDI_01wk_19820410.asc
# File downloaded successfully: EDDI_01wk_19820414.asc
# File downloaded successfully: EDDI_01wk_19820415.asc
# File downloaded successfully: EDDI_01wk_19820416.asc
# File downloaded successfully: EDDI_01wk_19820417.asc
# File downloaded successfully: EDDI_01wk_19820419.asc
# File downloaded successfully: EDDI_01wk_19820420.asc
# File downloaded successfully: EDDI_01wk_19820418.asc
# File downloaded successfully: EDDI_01wk_19820422.asc
# File downloaded successfully: EDDI_01wk_19820421.asc
# File downloaded successfully: EDDI_01wk_19820423.asc
# File downloaded successfully: EDDI_01wk_19820424.asc
# File downloaded successfully: EDDI_01wk_19820425.asc
# File downloaded successfully: EDDI_01wk_19820426.asc
# File downloaded successfully: EDDI_01wk_19820428.asc
# File downloaded successfully: EDDI_01wk_19820427.asc
# File downloaded successfully: EDDI_01wk_19820430.asc
# File downloaded successfully: EDDI_01wk_19820429.asc
# File downloaded successfully: EDDI_01wk_19820501.asc
# File downloaded successfully: EDDI_01wk_19820502.asc
# File downloaded successfully: EDDI_01wk_19820503.asc
# File downloaded successfully: EDDI_01wk_19820504.asc
# File downloaded successfully: EDDI_01wk_19820505.asc
# File downloaded successfully: EDDI_01wk_19820506.asc
# File downloaded successfully: EDDI_01wk_19820507.asc
# File downloaded successfully: EDDI_01wk_19820508.asc
# File downloaded successfully: EDDI_01wk_19820509.asc
# File downloaded successfully: EDDI_01wk_19820510.asc
# File downloaded successfully: EDDI_01wk_19820511.asc
# File downloaded successfully: EDDI_01wk_19820513.asc
# File downloaded successfully: EDDI_01wk_19820514.asc
# File downloaded successfully: EDDI_01wk_19820512.asc
# File downloaded successfully: EDDI_01wk_19820516.asc
# File downloaded successfully: EDDI_01wk_19820517.asc
# File downloaded successfully: EDDI_01wk_19820518.asc
# File downloaded successfully: EDDI_01wk_19820519.asc
# File downloaded successfully: EDDI_01wk_19820520.asc
# File downloaded successfully: EDDI_01wk_19820522.asc
# File downloaded successfully: EDDI_01wk_19820521.asc
# File downloaded successfully: EDDI_01wk_19820523.asc
# File downloaded successfully: EDDI_01wk_19820524.asc
# File downloaded successfully: EDDI_01wk_19820526.asc
# File downloaded successfully: EDDI_01wk_19820525.asc
# File downloaded successfully: EDDI_01wk_19820527.asc
# File downloaded successfully: EDDI_01wk_19820529.asc
# File downloaded successfully: EDDI_01wk_19820528.asc
# File downloaded successfully: EDDI_01wk_19820530.asc
# File downloaded successfully: EDDI_01wk_19820531.asc
# File downloaded successfully: EDDI_01wk_19820601.asc
# File downloaded successfully: EDDI_01wk_19820602.asc
# File downloaded successfully: EDDI_01wk_19820603.asc
# File downloaded successfully: EDDI_01wk_19820604.asc
# File downloaded successfully: EDDI_01wk_19820605.asc
# File downloaded successfully: EDDI_01wk_19820606.asc
# File downloaded successfully: EDDI_01wk_19820607.asc
# File downloaded successfully: EDDI_01wk_19820609.asc
# File downloaded successfully: EDDI_01wk_19820608.asc
# File downloaded successfully: EDDI_01wk_19820515.asc
# File downloaded successfully: EDDI_01wk_19820610.asc
# File downloaded successfully: EDDI_01wk_19820611.asc
# File downloaded successfully: EDDI_01wk_19820612.asc
# File downloaded successfully: EDDI_01wk_19820613.asc
# File downloaded successfully: EDDI_01wk_19820616.asc
# File downloaded successfully: EDDI_01wk_19820615.asc
# File downloaded successfully: EDDI_01wk_19820614.asc
# File downloaded successfully: EDDI_01wk_19820618.asc
# File downloaded successfully: EDDI_01wk_19820619.asc
# File downloaded successfully: EDDI_01wk_19820620.asc
# File downloaded successfully: EDDI_01wk_19820621.asc
# File downloaded successfully: EDDI_01wk_19820623.asc
# File downloaded successfully: EDDI_01wk_19820622.asc
# File downloaded successfully: EDDI_01wk_19820624.asc
# File downloaded successfully: EDDI_01wk_19820626.asc
# File downloaded successfully: EDDI_01wk_19820625.asc
# File downloaded successfully: EDDI_01wk_19820627.asc
# File downloaded successfully: EDDI_01wk_19820628.asc
# File downloaded successfully: EDDI_01wk_19820629.asc
# File downloaded successfully: EDDI_01wk_19820630.asc
# File downloaded successfully: EDDI_01wk_19820617.asc
# File downloaded successfully: EDDI_01wk_19820701.asc
# File downloaded successfully: EDDI_01wk_19820703.asc
# File downloaded successfully: EDDI_01wk_19820705.asc
# File downloaded successfully: EDDI_01wk_19820704.asc
# File downloaded successfully: EDDI_01wk_19820706.asc
# File downloaded successfully: EDDI_01wk_19820707.asc
# File downloaded successfully: EDDI_01wk_19820708.asc
# File downloaded successfully: EDDI_01wk_19820709.asc
# File downloaded successfully: EDDI_01wk_19820711.asc
# File downloaded successfully: EDDI_01wk_19820713.asc
# File downloaded successfully: EDDI_01wk_19820712.asc
# File downloaded successfully: EDDI_01wk_19820714.asc
# File downloaded successfully: EDDI_01wk_19820715.asc
# File downloaded successfully: EDDI_01wk_19820710.asc
# File downloaded successfully: EDDI_01wk_19820716.asc
# File downloaded successfully: EDDI_01wk_19820717.asc
# File downloaded successfully: EDDI_01wk_19820718.asc
# File downloaded successfully: EDDI_01wk_19820720.asc
# File downloaded successfully: EDDI_01wk_19820719.asc
# File downloaded successfully: EDDI_01wk_19820722.asc
# File downloaded successfully: EDDI_01wk_19820724.asc
# File downloaded successfully: EDDI_01wk_19820725.asc
# File downloaded successfully: EDDI_01wk_19820726.asc
# File downloaded successfully: EDDI_01wk_19820702.asc
# File downloaded successfully: EDDI_01wk_19820727.asc
# File downloaded successfully: EDDI_01wk_19820723.asc
# File downloaded successfully: EDDI_01wk_19820728.asc
# File downloaded successfully: EDDI_01wk_19820729.asc
# File downloaded successfully: EDDI_01wk_19820730.asc
# File downloaded successfully: EDDI_01wk_19820731.asc
# File downloaded successfully: EDDI_01wk_19820801.asc
# File downloaded successfully: EDDI_01wk_19820802.asc
# File downloaded successfully: EDDI_01wk_19820803.asc
# File downloaded successfully: EDDI_01wk_19820805.asc
# File downloaded successfully: EDDI_01wk_19820806.asc
# File downloaded successfully: EDDI_01wk_19820804.asc
# File downloaded successfully: EDDI_01wk_19820808.asc
# File downloaded successfully: EDDI_01wk_19820807.asc
# File downloaded successfully: EDDI_01wk_19820809.asc
# File downloaded successfully: EDDI_01wk_19820810.asc
# File downloaded successfully: EDDI_01wk_19820811.asc
# File downloaded successfully: EDDI_01wk_19820721.asc
# File downloaded successfully: EDDI_01wk_19820812.asc
# File downloaded successfully: EDDI_01wk_19820813.asc
# File downloaded successfully: EDDI_01wk_19820814.asc
# File downloaded successfully: EDDI_01wk_19820815.asc
# File downloaded successfully: EDDI_01wk_19820817.asc
# File downloaded successfully: EDDI_01wk_19820816.asc
# File downloaded successfully: EDDI_01wk_19820818.asc
# File downloaded successfully: EDDI_01wk_19820821.asc
# File downloaded successfully: EDDI_01wk_19820822.asc
# File downloaded successfully: EDDI_01wk_19820823.asc
# File downloaded successfully: EDDI_01wk_19820825.asc
# File downloaded successfully: EDDI_01wk_19820824.asc
# File downloaded successfully: EDDI_01wk_19820826.asc
# File downloaded successfully: EDDI_01wk_19820819.asc
# File downloaded successfully: EDDI_01wk_19820827.asc
# File downloaded successfully: EDDI_01wk_19820820.asc
# File downloaded successfully: EDDI_01wk_19820828.asc
# File downloaded successfully: EDDI_01wk_19820829.asc
# File downloaded successfully: EDDI_01wk_19820830.asc
# File downloaded successfully: EDDI_01wk_19820831.asc
# File downloaded successfully: EDDI_01wk_19820901.asc
# File downloaded successfully: EDDI_01wk_19820903.asc
# File downloaded successfully: EDDI_01wk_19820904.asc
# File downloaded successfully: EDDI_01wk_19820902.asc
# File downloaded successfully: EDDI_01wk_19820906.asc
# File downloaded successfully: EDDI_01wk_19820907.asc
# File downloaded successfully: EDDI_01wk_19820910.asc
# File downloaded successfully: EDDI_01wk_19820908.asc
# File downloaded successfully: EDDI_01wk_19820909.asc
# File downloaded successfully: EDDI_01wk_19820911.asc
# File downloaded successfully: EDDI_01wk_19820905.asc
# File downloaded successfully: EDDI_01wk_19820914.asc
# File downloaded successfully: EDDI_01wk_19820912.asc
# File downloaded successfully: EDDI_01wk_19820913.asc
# File downloaded successfully: EDDI_01wk_19820915.asc
# File downloaded successfully: EDDI_01wk_19820918.asc
# File downloaded successfully: EDDI_01wk_19820917.asc
# File downloaded successfully: EDDI_01wk_19820919.asc
# File downloaded successfully: EDDI_01wk_19820920.asc
# File downloaded successfully: EDDI_01wk_19820916.asc
# File downloaded successfully: EDDI_01wk_19820922.asc
# File downloaded successfully: EDDI_01wk_19820921.asc
# File downloaded successfully: EDDI_01wk_19820925.asc
# File downloaded successfully: EDDI_01wk_19820924.asc
# File downloaded successfully: EDDI_01wk_19820926.asc
# File downloaded successfully: EDDI_01wk_19820927.asc
# File downloaded successfully: EDDI_01wk_19820928.asc
# File downloaded successfully: EDDI_01wk_19820929.asc
# File downloaded successfully: EDDI_01wk_19820930.asc
# File downloaded successfully: EDDI_01wk_19821001.asc
# File downloaded successfully: EDDI_01wk_19821002.asc
# File downloaded successfully: EDDI_01wk_19821003.asc
# File downloaded successfully: EDDI_01wk_19821004.asc
# File downloaded successfully: EDDI_01wk_19821005.asc
# File downloaded successfully: EDDI_01wk_19821006.asc
# File downloaded successfully: EDDI_01wk_19821007.asc
# File downloaded successfully: EDDI_01wk_19821009.asc
# File downloaded successfully: EDDI_01wk_19821008.asc
# File downloaded successfully: EDDI_01wk_19821011.asc
# File downloaded successfully: EDDI_01wk_19821010.asc
# File downloaded successfully: EDDI_01wk_19821012.asc
# File downloaded successfully: EDDI_01wk_19821013.asc
# File downloaded successfully: EDDI_01wk_19821014.asc
# File downloaded successfully: EDDI_01wk_19821015.asc
# File downloaded successfully: EDDI_01wk_19821018.asc
# File downloaded successfully: EDDI_01wk_19821016.asc
# File downloaded successfully: EDDI_01wk_19821017.asc
# File downloaded successfully: EDDI_01wk_19821019.asc
# File downloaded successfully: EDDI_01wk_19821020.asc
# File downloaded successfully: EDDI_01wk_19821021.asc
# File downloaded successfully: EDDI_01wk_19820923.asc
# File downloaded successfully: EDDI_01wk_19821022.asc
# File downloaded successfully: EDDI_01wk_19821023.asc
# File downloaded successfully: EDDI_01wk_19821024.asc
# File downloaded successfully: EDDI_01wk_19821026.asc
# File downloaded successfully: EDDI_01wk_19821025.asc
# File downloaded successfully: EDDI_01wk_19821027.asc
# File downloaded successfully: EDDI_01wk_19821028.asc
# File downloaded successfully: EDDI_01wk_19821029.asc
# File downloaded successfully: EDDI_01wk_19821101.asc
# File downloaded successfully: EDDI_01wk_19821031.asc
# File downloaded successfully: EDDI_01wk_19821102.asc
# File downloaded successfully: EDDI_01wk_19821103.asc
# File downloaded successfully: EDDI_01wk_19821104.asc
# File downloaded successfully: EDDI_01wk_19821106.asc
# File downloaded successfully: EDDI_01wk_19821105.asc
# File downloaded successfully: EDDI_01wk_19821030.asc
# File downloaded successfully: EDDI_01wk_19821108.asc
# File downloaded successfully: EDDI_01wk_19821107.asc
# File downloaded successfully: EDDI_01wk_19821109.asc
# File downloaded successfully: EDDI_01wk_19821110.asc
# File downloaded successfully: EDDI_01wk_19821111.asc
# File downloaded successfully: EDDI_01wk_19821113.asc
# File downloaded successfully: EDDI_01wk_19821112.asc
# File downloaded successfully: EDDI_01wk_19821114.asc
# File downloaded successfully: EDDI_01wk_19821115.asc
# File downloaded successfully: EDDI_01wk_19821116.asc
# File downloaded successfully: EDDI_01wk_19821118.asc
# File downloaded successfully: EDDI_01wk_19821117.asc
# File downloaded successfully: EDDI_01wk_19821119.asc
# File downloaded successfully: EDDI_01wk_19821120.asc
# File downloaded successfully: EDDI_01wk_19821121.asc
# File downloaded successfully: EDDI_01wk_19821123.asc
# File downloaded successfully: EDDI_01wk_19821124.asc
# File downloaded successfully: EDDI_01wk_19821122.asc
# File downloaded successfully: EDDI_01wk_19821125.asc
# File downloaded successfully: EDDI_01wk_19821126.asc
# File downloaded successfully: EDDI_01wk_19821127.asc
# File downloaded successfully: EDDI_01wk_19821129.asc
# File downloaded successfully: EDDI_01wk_19821128.asc
# File downloaded successfully: EDDI_01wk_19821201.asc
# File downloaded successfully: EDDI_01wk_19821130.asc
# File downloaded successfully: EDDI_01wk_19821202.asc
# File downloaded successfully: EDDI_01wk_19821203.asc
# File downloaded successfully: EDDI_01wk_19821205.asc
# File downloaded successfully: EDDI_01wk_19821204.asc
# File downloaded successfully: EDDI_01wk_19821206.asc
# File downloaded successfully: EDDI_01wk_19821207.asc
# File downloaded successfully: EDDI_01wk_19821209.asc
# File downloaded successfully: EDDI_01wk_19821208.asc
# File downloaded successfully: EDDI_01wk_19821210.asc
# File downloaded successfully: EDDI_01wk_19821211.asc
# File downloaded successfully: EDDI_01wk_19821212.asc
# File downloaded successfully: EDDI_01wk_19821213.asc
# File downloaded successfully: EDDI_01wk_19821214.asc
# File downloaded successfully: EDDI_01wk_19821215.asc
# File downloaded successfully: EDDI_01wk_19821216.asc
# File downloaded successfully: EDDI_01wk_19821217.asc
# File downloaded successfully: EDDI_01wk_19821218.asc
# File downloaded successfully: EDDI_01wk_19821219.asc
# File downloaded successfully: EDDI_01wk_19821220.asc
# File downloaded successfully: EDDI_01wk_19821222.asc
# File downloaded successfully: EDDI_01wk_19821221.asc
# File downloaded successfully: EDDI_01wk_19821223.asc
# File downloaded successfully: EDDI_01wk_19821225.asc
# File downloaded successfully: EDDI_01wk_19821224.asc
# File downloaded successfully: EDDI_01wk_19821226.asc
# File downloaded successfully: EDDI_01wk_19821227.asc
# File downloaded successfully: EDDI_01wk_19821228.asc
# File downloaded successfully: EDDI_01wk_19821230.asc
# File downloaded successfully: EDDI_01wk_19821229.asc
# File downloaded successfully: EDDI_01wk_19821231.asc
# Data for year 1982 processed and saved as Parquet at /teamspace/studios/this_studio/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/eddi/EDDI_01wk_1982.parquet.
# File downloaded successfully: EDDI_01wk_19830107.asc
# File downloaded successfully: EDDI_01wk_19830102.asc
# File downloaded successfully: EDDI_01wk_19830101.asc
# File downloaded successfully: EDDI_01wk_19830106.asc
# File downloaded successfully: EDDI_01wk_19830108.asc
# File downloaded successfully: EDDI_01wk_19830103.asc
# File downloaded successfully: EDDI_01wk_19830104.asc
# File downloaded successfully: EDDI_01wk_19830105.asc
# File downloaded successfully: EDDI_01wk_19830109.asc
# File downloaded successfully: EDDI_01wk_19830111.asc
# File downloaded successfully: EDDI_01wk_19830113.asc
# File downloaded successfully: EDDI_01wk_19830112.asc
# File downloaded successfully: EDDI_01wk_19830110.asc
# File downloaded successfully: EDDI_01wk_19830114.asc
# File downloaded successfully: EDDI_01wk_19830116.asc
# File downloaded successfully: EDDI_01wk_19830115.asc
# File downloaded successfully: EDDI_01wk_19830119.asc
# File downloaded successfully: EDDI_01wk_19830117.asc
# File downloaded successfully: EDDI_01wk_19830118.asc
# File downloaded successfully: EDDI_01wk_19830121.asc
# File downloaded successfully: EDDI_01wk_19830122.asc
# File downloaded successfully: EDDI_01wk_19830120.asc
# File downloaded successfully: EDDI_01wk_19830123.asc
# File downloaded successfully: EDDI_01wk_19830124.asc
# File downloaded successfully: EDDI_01wk_19830125.asc
# File downloaded successfully: EDDI_01wk_19830126.asc
# File downloaded successfully: EDDI_01wk_19830127.asc
# File downloaded successfully: EDDI_01wk_19830128.asc
# File downloaded successfully: EDDI_01wk_19830129.asc
# File downloaded successfully: EDDI_01wk_19830131.asc
# File downloaded successfully: EDDI_01wk_19830130.asc
# File downloaded successfully: EDDI_01wk_19830201.asc
# File downloaded successfully: EDDI_01wk_19830202.asc
# File downloaded successfully: EDDI_01wk_19830204.asc
# File downloaded successfully: EDDI_01wk_19830203.asc
# File downloaded successfully: EDDI_01wk_19830205.asc
# File downloaded successfully: EDDI_01wk_19830206.asc
# File downloaded successfully: EDDI_01wk_19830208.asc
# File downloaded successfully: EDDI_01wk_19830207.asc
# File downloaded successfully: EDDI_01wk_19830209.asc
# File downloaded successfully: EDDI_01wk_19830210.asc
# File downloaded successfully: EDDI_01wk_19830212.asc
# File downloaded successfully: EDDI_01wk_19830211.asc
# File downloaded successfully: EDDI_01wk_19830213.asc
# File downloaded successfully: EDDI_01wk_19830215.asc
# File downloaded successfully: EDDI_01wk_19830216.asc
# File downloaded successfully: EDDI_01wk_19830214.asc
# File downloaded successfully: EDDI_01wk_19830218.asc
# File downloaded successfully: EDDI_01wk_19830219.asc
# File downloaded successfully: EDDI_01wk_19830220.asc
# File downloaded successfully: EDDI_01wk_19830221.asc
# File downloaded successfully: EDDI_01wk_19830222.asc
# File downloaded successfully: EDDI_01wk_19830223.asc
# File downloaded successfully: EDDI_01wk_19830224.asc
# File downloaded successfully: EDDI_01wk_19830225.asc
# File downloaded successfully: EDDI_01wk_19830227.asc
# File downloaded successfully: EDDI_01wk_19830226.asc
# File downloaded successfully: EDDI_01wk_19830228.asc
# File downloaded successfully: EDDI_01wk_19830301.asc
# File downloaded successfully: EDDI_01wk_19830302.asc
# File downloaded successfully: EDDI_01wk_19830303.asc
# File downloaded successfully: EDDI_01wk_19830304.asc
# File downloaded successfully: EDDI_01wk_19830305.asc
# File downloaded successfully: EDDI_01wk_19830306.asc
# File downloaded successfully: EDDI_01wk_19830307.asc
# File downloaded successfully: EDDI_01wk_19830308.asc
# File downloaded successfully: EDDI_01wk_19830309.asc
# File downloaded successfully: EDDI_01wk_19830310.asc
# File downloaded successfully: EDDI_01wk_19830311.asc
# File downloaded successfully: EDDI_01wk_19830312.asc
# File downloaded successfully: EDDI_01wk_19830217.asc
# File downloaded successfully: EDDI_01wk_19830314.asc
# File downloaded successfully: EDDI_01wk_19830313.asc
# File downloaded successfully: EDDI_01wk_19830315.asc
# File downloaded successfully: EDDI_01wk_19830317.asc
# File downloaded successfully: EDDI_01wk_19830318.asc
# File downloaded successfully: EDDI_01wk_19830319.asc
# File downloaded successfully: EDDI_01wk_19830316.asc
# File downloaded successfully: EDDI_01wk_19830321.asc
# File downloaded successfully: EDDI_01wk_19830322.asc
# File downloaded successfully: EDDI_01wk_19830323.asc
# File downloaded successfully: EDDI_01wk_19830324.asc
# File downloaded successfully: EDDI_01wk_19830325.asc
# File downloaded successfully: EDDI_01wk_19830326.asc
# File downloaded successfully: EDDI_01wk_19830328.asc
# File downloaded successfully: EDDI_01wk_19830330.asc
# File downloaded successfully: EDDI_01wk_19830329.asc
# File downloaded successfully: EDDI_01wk_19830320.asc
# File downloaded successfully: EDDI_01wk_19830331.asc
# File downloaded successfully: EDDI_01wk_19830401.asc
# File downloaded successfully: EDDI_01wk_19830402.asc
# File downloaded successfully: EDDI_01wk_19830403.asc
# File downloaded successfully: EDDI_01wk_19830404.asc
# File downloaded successfully: EDDI_01wk_19830406.asc
# File downloaded successfully: EDDI_01wk_19830405.asc
# File downloaded successfully: EDDI_01wk_19830409.asc
# File downloaded successfully: EDDI_01wk_19830408.asc
# File downloaded successfully: EDDI_01wk_19830407.asc
# File downloaded successfully: EDDI_01wk_19830410.asc
# File downloaded successfully: EDDI_01wk_19830411.asc
# File downloaded successfully: EDDI_01wk_19830412.asc
# File downloaded successfully: EDDI_01wk_19830413.asc
# File downloaded successfully: EDDI_01wk_19830415.asc
# File downloaded successfully: EDDI_01wk_19830414.asc
# File downloaded successfully: EDDI_01wk_19830416.asc
# File downloaded successfully: EDDI_01wk_19830418.asc
# File downloaded successfully: EDDI_01wk_19830419.asc
# File downloaded successfully: EDDI_01wk_19830417.asc
# File downloaded successfully: EDDI_01wk_19830420.asc
# File downloaded successfully: EDDI_01wk_19830327.asc
# File downloaded successfully: EDDI_01wk_19830421.asc
# File downloaded successfully: EDDI_01wk_19830422.asc
# File downloaded successfully: EDDI_01wk_19830423.asc
# File downloaded successfully: EDDI_01wk_19830424.asc
# File downloaded successfully: EDDI_01wk_19830425.asc
# File downloaded successfully: EDDI_01wk_19830426.asc
# File downloaded successfully: EDDI_01wk_19830427.asc
# File downloaded successfully: EDDI_01wk_19830428.asc
# File downloaded successfully: EDDI_01wk_19830430.asc
# File downloaded successfully: EDDI_01wk_19830501.asc
# File downloaded successfully: EDDI_01wk_19830502.asc
# File downloaded successfully: EDDI_01wk_19830503.asc
# File downloaded successfully: EDDI_01wk_19830504.asc
# File downloaded successfully: EDDI_01wk_19830505.asc
# File downloaded successfully: EDDI_01wk_19830506.asc
# File downloaded successfully: EDDI_01wk_19830507.asc
# File downloaded successfully: EDDI_01wk_19830508.asc
# File downloaded successfully: EDDI_01wk_19830429.asc
# File downloaded successfully: EDDI_01wk_19830509.asc
# File downloaded successfully: EDDI_01wk_19830510.asc
# File downloaded successfully: EDDI_01wk_19830511.asc
# File downloaded successfully: EDDI_01wk_19830512.asc
# File downloaded successfully: EDDI_01wk_19830513.asc
# File downloaded successfully: EDDI_01wk_19830514.asc
# File downloaded successfully: EDDI_01wk_19830515.asc
# File downloaded successfully: EDDI_01wk_19830517.asc
# File downloaded successfully: EDDI_01wk_19830518.asc
# File downloaded successfully: EDDI_01wk_19830519.asc
# File downloaded successfully: EDDI_01wk_19830516.asc
# File downloaded successfully: EDDI_01wk_19830520.asc
# File downloaded successfully: EDDI_01wk_19830521.asc
# File downloaded successfully: EDDI_01wk_19830522.asc
# File downloaded successfully: EDDI_01wk_19830523.asc
# File downloaded successfully: EDDI_01wk_19830524.asc
# File downloaded successfully: EDDI_01wk_19830525.asc
# File downloaded successfully: EDDI_01wk_19830526.asc
# File downloaded successfully: EDDI_01wk_19830528.asc
# File downloaded successfully: EDDI_01wk_19830527.asc
# File downloaded successfully: EDDI_01wk_19830529.asc
# File downloaded successfully: EDDI_01wk_19830530.asc
# File downloaded successfully: EDDI_01wk_19830531.asc
# File downloaded successfully: EDDI_01wk_19830601.asc
# File downloaded successfully: EDDI_01wk_19830603.asc
# File downloaded successfully: EDDI_01wk_19830602.asc
# File downloaded successfully: EDDI_01wk_19830604.asc
# File downloaded successfully: EDDI_01wk_19830605.asc
# File downloaded successfully: EDDI_01wk_19830606.asc
# File downloaded successfully: EDDI_01wk_19830607.asc
# File downloaded successfully: EDDI_01wk_19830609.asc
# File downloaded successfully: EDDI_01wk_19830610.asc
# File downloaded successfully: EDDI_01wk_19830611.asc
# File downloaded successfully: EDDI_01wk_19830612.asc
# File downloaded successfully: EDDI_01wk_19830608.asc
# File downloaded successfully: EDDI_01wk_19830613.asc
# File downloaded successfully: EDDI_01wk_19830614.asc
# File downloaded successfully: EDDI_01wk_19830615.asc
# File downloaded successfully: EDDI_01wk_19830616.asc
# File downloaded successfully: EDDI_01wk_19830617.asc
# File downloaded successfully: EDDI_01wk_19830618.asc
# ...
# File downloaded successfully: EDDI_01wk_19831219.asc
# File downloaded successfully: EDDI_01wk_19831221.asc
# File downloaded successfully: EDDI_01wk_19831222.asc
# File downloaded successfully: EDDI_01wk_19831220.asc
# File downloaded successfully: EDDI_01wk_19831223.asc
# File downloaded successfully: EDDI_01wk_19831224.asc
# File downloaded successfully: EDDI_01wk_19831225.asc
# File downloaded successfully: EDDI_01wk_19831226.asc
# File downloaded successfully: EDDI_01wk_19831227.asc
# File downloaded successfully: EDDI_01wk_19831228.asc
# File downloaded successfully: EDDI_01wk_19831229.asc
# File downloaded successfully: EDDI_01wk_19831230.asc
# File downloaded successfully: EDDI_01wk_19831231.asc
# File downloaded successfully: EDDI_01wk_19831211.asc
# Data for year 1983 processed and saved as Parquet at /teamspace/studios/this_studio/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/eddi/EDDI_01wk_1983.parquet.
# File downloaded successfully: EDDI_01wk_19840102.asc
# File downloaded successfully: EDDI_01wk_19840105.asc
# File downloaded successfully: EDDI_01wk_19840106.asc
# File downloaded successfully: EDDI_01wk_19840104.asc
# File downloaded successfully: EDDI_01wk_19840108.asc
# File downloaded successfully: EDDI_01wk_19840103.asc
# File downloaded successfully: EDDI_01wk_19840107.asc
# File downloaded successfully: EDDI_01wk_19840109.asc
# File downloaded successfully: EDDI_01wk_19840101.asc
# File downloaded successfully: EDDI_01wk_19840111.asc
# File downloaded successfully: EDDI_01wk_19840113.asc
# File downloaded successfully: EDDI_01wk_19840112.asc
# File downloaded successfully: EDDI_01wk_19840117.asc
# File downloaded successfully: EDDI_01wk_19840116.asc
# File downloaded successfully: EDDI_01wk_19840119.asc
# File downloaded successfully: EDDI_01wk_19840120.asc
# File downloaded successfully: EDDI_01wk_19840115.asc
# File downloaded successfully: EDDI_01wk_19840114.asc
# File downloaded successfully: EDDI_01wk_19840118.asc
# File downloaded successfully: EDDI_01wk_19840121.asc
# File downloaded successfully: EDDI_01wk_19840122.asc
# File downloaded successfully: EDDI_01wk_19840110.asc
# File downloaded successfully: EDDI_01wk_19840123.asc
# File downloaded successfully: EDDI_01wk_19840125.asc
# File downloaded successfully: EDDI_01wk_19840126.asc
# File downloaded successfully: EDDI_01wk_19840124.asc
# File downloaded successfully: EDDI_01wk_19840127.asc
# File downloaded successfully: EDDI_01wk_19840128.asc
# File downloaded successfully: EDDI_01wk_19840129.asc
# File downloaded successfully: EDDI_01wk_19840130.asc
# File downloaded successfully: EDDI_01wk_19840201.asc
# File downloaded successfully: EDDI_01wk_19840202.asc
# File downloaded successfully: EDDI_01wk_19840204.asc
# File downloaded successfully: EDDI_01wk_19840203.asc
# File downloaded successfully: EDDI_01wk_19840131.asc
# File downloaded successfully: EDDI_01wk_19840205.asc
# File downloaded successfully: EDDI_01wk_19840207.asc
# File downloaded successfully: EDDI_01wk_19840206.asc
# File downloaded successfully: EDDI_01wk_19840208.asc
# File downloaded successfully: EDDI_01wk_19840209.asc
# File downloaded successfully: EDDI_01wk_19840210.asc
# File downloaded successfully: EDDI_01wk_19840214.asc
# File downloaded successfully: EDDI_01wk_19840212.asc
# File downloaded successfully: EDDI_01wk_19840213.asc
# File downloaded successfully: EDDI_01wk_19840217.asc
# File downloaded successfully: EDDI_01wk_19840215.asc
# File downloaded successfully: EDDI_01wk_19840216.asc
# File downloaded successfully: EDDI_01wk_19840218.asc
# File downloaded successfully: EDDI_01wk_19840211.asc
# File downloaded successfully: EDDI_01wk_19840219.asc
# File downloaded successfully: EDDI_01wk_19840220.asc
# File downloaded successfully: EDDI_01wk_19840221.asc
# File downloaded successfully: EDDI_01wk_19840222.asc
# File downloaded successfully: EDDI_01wk_19840223.asc
# File downloaded successfully: EDDI_01wk_19840225.asc
# File downloaded successfully: EDDI_01wk_19840224.asc
# File downloaded successfully: EDDI_01wk_19840228.asc
# File downloaded successfully: EDDI_01wk_19840301.asc
# File downloaded successfully: EDDI_01wk_19840226.asc
# File downloaded successfully: EDDI_01wk_19840227.asc
# File downloaded successfully: EDDI_01wk_19840302.asc
# File downloaded successfully: EDDI_01wk_19840304.asc
# File downloaded successfully: EDDI_01wk_19840303.asc
# File downloaded successfully: EDDI_01wk_19840305.asc
# File downloaded successfully: EDDI_01wk_19840307.asc
# File downloaded successfully: EDDI_01wk_19840306.asc
# File downloaded successfully: EDDI_01wk_19840310.asc
# File downloaded successfully: EDDI_01wk_19840308.asc
# File downloaded successfully: EDDI_01wk_19840309.asc
# File downloaded successfully: EDDI_01wk_19840311.asc
# File downloaded successfully: EDDI_01wk_19840313.asc
# File downloaded successfully: EDDI_01wk_19840312.asc
# File downloaded successfully: EDDI_01wk_19840315.asc
# File downloaded successfully: EDDI_01wk_19840314.asc
# File downloaded successfully: EDDI_01wk_19840316.asc
# File downloaded successfully: EDDI_01wk_19840317.asc
# File downloaded successfully: EDDI_01wk_19840318.asc
# File downloaded successfully: EDDI_01wk_19840319.asc
# File downloaded successfully: EDDI_01wk_19840323.asc
# File downloaded successfully: EDDI_01wk_19840320.asc
# File downloaded successfully: EDDI_01wk_19840322.asc
# File downloaded successfully: EDDI_01wk_19840321.asc
# File downloaded successfully: EDDI_01wk_19840324.asc
# File downloaded successfully: EDDI_01wk_19840326.asc
# File downloaded successfully: EDDI_01wk_19840329.asc
# File downloaded successfully: EDDI_01wk_19840327.asc
# File downloaded successfully: EDDI_01wk_19840325.asc
# File downloaded successfully: EDDI_01wk_19840328.asc
# File downloaded successfully: EDDI_01wk_19840331.asc
# File downloaded successfully: EDDI_01wk_19840330.asc
# File downloaded successfully: EDDI_01wk_19840401.asc
# File downloaded successfully: EDDI_01wk_19840402.asc
# File downloaded successfully: EDDI_01wk_19840403.asc
# File downloaded successfully: EDDI_01wk_19840404.asc
# File downloaded successfully: EDDI_01wk_19840405.asc
# File downloaded successfully: EDDI_01wk_19840408.asc
# File downloaded successfully: EDDI_01wk_19840409.asc
# File downloaded successfully: EDDI_01wk_19840410.asc
# File downloaded successfully: EDDI_01wk_19840407.asc
# File downloaded successfully: EDDI_01wk_19840412.asc
# File downloaded successfully: EDDI_01wk_19840411.asc
# File downloaded successfully: EDDI_01wk_19840414.asc
# File downloaded successfully: EDDI_01wk_19840415.asc
# File downloaded successfully: EDDI_01wk_19840416.asc
# File downloaded successfully: EDDI_01wk_19840417.asc
# File downloaded successfully: EDDI_01wk_19840418.asc
# File downloaded successfully: EDDI_01wk_19840413.asc
# File downloaded successfully: EDDI_01wk_19840419.asc
# File downloaded successfully: EDDI_01wk_19840420.asc
# File downloaded successfully: EDDI_01wk_19840421.asc
# File downloaded successfully: EDDI_01wk_19840422.asc
# File downloaded successfully: EDDI_01wk_19840424.asc
# File downloaded successfully: EDDI_01wk_19840423.asc
# File downloaded successfully: EDDI_01wk_19840425.asc
# File downloaded successfully: EDDI_01wk_19840427.asc
# File downloaded successfully: EDDI_01wk_19840406.asc
# File downloaded successfully: EDDI_01wk_19840426.asc
# File downloaded successfully: EDDI_01wk_19840428.asc
# File downloaded successfully: EDDI_01wk_19840430.asc
# File downloaded successfully: EDDI_01wk_19840429.asc
# File downloaded successfully: EDDI_01wk_19840501.asc
# File downloaded successfully: EDDI_01wk_19840502.asc
# File downloaded successfully: EDDI_01wk_19840503.asc
# File downloaded successfully: EDDI_01wk_19840504.asc
# File downloaded successfully: EDDI_01wk_19840506.asc
# File downloaded successfully: EDDI_01wk_19840505.asc
# File downloaded successfully: EDDI_01wk_19840507.asc
# File downloaded successfully: EDDI_01wk_19840509.asc
# File downloaded successfully: EDDI_01wk_19840510.asc
# File downloaded successfully: EDDI_01wk_19840512.asc
# File downloaded successfully: EDDI_01wk_19840511.asc
# File downloaded successfully: EDDI_01wk_19840513.asc
# File downloaded successfully: EDDI_01wk_19840514.asc
# File downloaded successfully: EDDI_01wk_19840515.asc
# File downloaded successfully: EDDI_01wk_19840508.asc
# File downloaded successfully: EDDI_01wk_19840516.asc
# File downloaded successfully: EDDI_01wk_19840518.asc
# File downloaded successfully: EDDI_01wk_19840517.asc
# File downloaded successfully: EDDI_01wk_19840519.asc
# File downloaded successfully: EDDI_01wk_19840520.asc
# File downloaded successfully: EDDI_01wk_19840521.asc
# File downloaded successfully: EDDI_01wk_19840522.asc
# File downloaded successfully: EDDI_01wk_19840523.asc
# File downloaded successfully: EDDI_01wk_19840524.asc
# File downloaded successfully: EDDI_01wk_19840525.asc
# File downloaded successfully: EDDI_01wk_19840526.asc
# File downloaded successfully: EDDI_01wk_19840529.asc
# File downloaded successfully: EDDI_01wk_19840527.asc
# File downloaded successfully: EDDI_01wk_19840528.asc
# File downloaded successfully: EDDI_01wk_19840530.asc
# File downloaded successfully: EDDI_01wk_19840531.asc
# File downloaded successfully: EDDI_01wk_19840601.asc
# File downloaded successfully: EDDI_01wk_19840603.asc
# File downloaded successfully: EDDI_01wk_19840602.asc
# File downloaded successfully: EDDI_01wk_19840604.asc
# File downloaded successfully: EDDI_01wk_19840605.asc
# File downloaded successfully: EDDI_01wk_19840607.asc
# File downloaded successfully: EDDI_01wk_19840606.asc
# File downloaded successfully: EDDI_01wk_19840608.asc
# File downloaded successfully: EDDI_01wk_19840611.asc
# File downloaded successfully: EDDI_01wk_19840609.asc
# File downloaded successfully: EDDI_01wk_19840613.asc
# File downloaded successfully: EDDI_01wk_19840610.asc
# File downloaded successfully: EDDI_01wk_19840612.asc
# File downloaded successfully: EDDI_01wk_19840615.asc
# File downloaded successfully: EDDI_01wk_19840614.asc
# File downloaded successfully: EDDI_01wk_19840616.asc
# File downloaded successfully: EDDI_01wk_19840617.asc
# File downloaded successfully: EDDI_01wk_19840618.asc
# File downloaded successfully: EDDI_01wk_19840619.asc
# File downloaded successfully: EDDI_01wk_19840620.asc
# File downloaded successfully: EDDI_01wk_19840621.asc
# File downloaded successfully: EDDI_01wk_19840622.asc
# File downloaded successfully: EDDI_01wk_19840623.asc
# File downloaded successfully: EDDI_01wk_19840624.asc
# File downloaded successfully: EDDI_01wk_19840625.asc
# File downloaded successfully: EDDI_01wk_19840626.asc
# File downloaded successfully: EDDI_01wk_19840627.asc
# File downloaded successfully: EDDI_01wk_19840628.asc
# File downloaded successfully: EDDI_01wk_19840701.asc
# File downloaded successfully: EDDI_01wk_19840629.asc
# File downloaded successfully: EDDI_01wk_19840630.asc
# File downloaded successfully: EDDI_01wk_19840702.asc
# File downloaded successfully: EDDI_01wk_19840703.asc
# File downloaded successfully: EDDI_01wk_19840705.asc
# File downloaded successfully: EDDI_01wk_19840704.asc
# File downloaded successfully: EDDI_01wk_19840706.asc
# File downloaded successfully: EDDI_01wk_19840708.asc
# File downloaded successfully: EDDI_01wk_19840707.asc
# File downloaded successfully: EDDI_01wk_19840709.asc
# File downloaded successfully: EDDI_01wk_19840710.asc
# File downloaded successfully: EDDI_01wk_19840711.asc
# File downloaded successfully: EDDI_01wk_19840713.asc
# File downloaded successfully: EDDI_01wk_19840712.asc
# File downloaded successfully: EDDI_01wk_19840714.asc
# File downloaded successfully: EDDI_01wk_19840716.asc
# File downloaded successfully: EDDI_01wk_19840715.asc
# File downloaded successfully: EDDI_01wk_19840718.asc
# File downloaded successfully: EDDI_01wk_19840717.asc
# File downloaded successfully: EDDI_01wk_19840719.asc
# File downloaded successfully: EDDI_01wk_19840721.asc
# File downloaded successfully: EDDI_01wk_19840720.asc
# File downloaded successfully: EDDI_01wk_19840722.asc
# File downloaded successfully: EDDI_01wk_19840724.asc
# File downloaded successfully: EDDI_01wk_19840723.asc
# File downloaded successfully: EDDI_01wk_19840725.asc
# File downloaded successfully: EDDI_01wk_19840726.asc
# File downloaded successfully: EDDI_01wk_19840727.asc
# File downloaded successfully: EDDI_01wk_19840728.asc
# File downloaded successfully: EDDI_01wk_19840729.asc
# File downloaded successfully: EDDI_01wk_19840730.asc
# File downloaded successfully: EDDI_01wk_19840731.asc
# File downloaded successfully: EDDI_01wk_19840802.asc
# File downloaded successfully: EDDI_01wk_19840801.asc
# File downloaded successfully: EDDI_01wk_19840804.asc
# File downloaded successfully: EDDI_01wk_19840805.asc
# File downloaded successfully: EDDI_01wk_19840807.asc
# File downloaded successfully: EDDI_01wk_19840806.asc
# File downloaded successfully: EDDI_01wk_19840808.asc
# File downloaded successfully: EDDI_01wk_19840810.asc
# File downloaded successfully: EDDI_01wk_19840809.asc
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 8
#       5 file_types = ["01wk", "02wk", "01mn", "02mn", "03mn", "06mn", "09mn", "12mn"]
#       7 for file_type in file_types:
# ----> 8     download_and_process_raster_data(base_url, start_year, end_year, file_type, destination_folder)
#      10     # Construct the directory and output file paths
#      11     directory_path = '/teamspace/studios/this_studio/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/eddi'
#
# Cell In[7], line 20, in download_and_process_raster_data(base_url, start_year, end_year, file_type, destination_folder)
#      17     os.makedirs(year_destination_folder)
#      19 file_links = fetch_file_links(year_url, file_type)
# ---> 20 with ThreadPoolExecutor(max_workers=8) as executor:
#      21     executor.map(lambda url: download_file(url, year_destination_folder), file_links)
#      23 # Process and append raster data to a Polars DataFrame
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/concurrent/futures/_base.py:649, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     648 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 649     self.shutdown(wait=True)
#     650     return False
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/concurrent/futures/thread.py:235, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     233 if wait:
#     234     for t in self._threads:
# --> 235         t.join()
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:
# File downloaded successfully: EDDI_01wk_19840811.asc
# File downloaded successfully: EDDI_01wk_19840812.asc
# File downloaded successfully: EDDI_01wk_19840813.asc
# File downloaded successfully: EDDI_01wk_19840814.asc
# File downloaded successfully: EDDI_01wk_19840816.asc
# File downloaded successfully: EDDI_01wk_19840817.asc
# File downloaded successfully: EDDI_01wk_19840815.asc
# File downloaded successfully: EDDI_01wk_19840818.asc
# File downloaded successfully: EDDI_01wk_19840820.asc
# File downloaded successfully: EDDI_01wk_19840819.asc
# File downloaded successfully: EDDI_01wk_19840821.asc
# File downloaded successfully: EDDI_01wk_19840822.asc
# File downloaded successfully: EDDI_01wk_19840823.asc
# File downloaded successfully: EDDI_01wk_19840824.asc
# File downloaded successfully: EDDI_01wk_19840825.asc
# File downloaded successfully: EDDI_01wk_19840826.asc
# File downloaded successfully: EDDI_01wk_19840803.asc
# File downloaded successfully: EDDI_01wk_19840827.asc
# File downloaded successfully: EDDI_01wk_19840828.asc
# File downloaded successfully: EDDI_01wk_19840829.asc

# %% [markdown]
# # Testing functions

# %%
import polars as pl
# Define the path to your Parquet file
parquet_file_path_1 = "/teamspace/studios/this_studio/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw//merged_eddi_data_01wk.parquet"
parquet_file_path_2 = "/teamspace/studios/this_studio/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw//merged_eddi_data_02wk.parquet"


# Use Polars to read the Parquet file
df_1 = pl.read_parquet(parquet_file_path_1)
df_2 = pl.read_parquet(parquet_file_path_2)

# %%
df_1
# Out:
# shape: (62_374_360, 4)
# ┌────────────┬───────┬──────┬───────────┐
# │ time       ┆ lat   ┆ lon  ┆ eddi      │
# │ ---        ┆ ---   ┆ ---  ┆ ---       │
# │ str        ┆ f64   ┆ f64  ┆ f32       │
# ╞════════════╪═══════╪══════╪═══════════╡
# │ 1981-01-04 ┆ 22.0  ┆ 23.0 ┆ 0.000288  │
# │ 1981-01-04 ┆ 22.0  ┆ 23.5 ┆ -0.115403 │
# │ 1981-01-04 ┆ 22.0  ┆ 24.0 ┆ -0.29267  │
# │ 1981-01-04 ┆ 22.0  ┆ 24.5 ┆ -0.29267  │
# │ 1981-01-04 ┆ 22.0  ┆ 25.0 ┆ -0.415945 │
# │ …          ┆ …     ┆ …    ┆ …         │
# │ 2024-04-15 ┆ -11.5 ┆ 49.5 ┆ -999.0    │
# │ 2024-04-15 ┆ -11.5 ┆ 50.0 ┆ -999.0    │
# │ 2024-04-15 ┆ -11.5 ┆ 50.5 ┆ -999.0    │
# │ 2024-04-15 ┆ -11.5 ┆ 51.0 ┆ -999.0    │
# │ 2024-04-15 ┆ -11.5 ┆ 51.5 ┆ -999.0    │
# └────────────┴───────┴──────┴───────────┘

# %%
df_2
# Out:
# shape: (62_374_360, 4)
# ┌────────────┬───────┬──────┬───────────┐
# │ time       ┆ lat   ┆ lon  ┆ eddi      │
# │ ---        ┆ ---   ┆ ---  ┆ ---       │
# │ str        ┆ f64   ┆ f64  ┆ f32       │
# ╞════════════╪═══════╪══════╪═══════════╡
# │ 1981-01-07 ┆ 22.0  ┆ 23.0 ┆ -0.761296 │
# │ 1981-01-07 ┆ 22.0  ┆ 23.5 ┆ -0.479941 │
# │ 1981-01-07 ┆ 22.0  ┆ 24.0 ┆ -0.479941 │
# │ 1981-01-07 ┆ 22.0  ┆ 24.5 ┆ -0.353626 │
# │ 1981-01-07 ┆ 22.0  ┆ 25.0 ┆ -0.232805 │
# │ …          ┆ …     ┆ …    ┆ …         │
# │ 2024-04-29 ┆ -11.5 ┆ 49.5 ┆ -999.0    │
# │ 2024-04-29 ┆ -11.5 ┆ 50.0 ┆ -999.0    │
# │ 2024-04-29 ┆ -11.5 ┆ 50.5 ┆ -999.0    │
# │ 2024-04-29 ┆ -11.5 ┆ 51.0 ┆ -999.0    │
# │ 2024-04-29 ┆ -11.5 ┆ 51.5 ┆ -999.0    │
# └────────────┴───────┴──────┴───────────┘

# %%
import polars as pl

# Define the path to your Parquet files
parquet_file_path_1 = "/workspace/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/merged_eddi_data_01wk.parquet"
parquet_file_path_2 = "/workspace/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/merged_eddi_data_02wk.parquet"
parquet_file_path_3 = "/workspace/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/merged_eddi_data_01mn.parquet"

# Read the Parquet files
df_1 = pl.read_parquet(parquet_file_path_1)
df_2 = pl.read_parquet(parquet_file_path_2)
df_3 = pl.read_parquet(parquet_file_path_3)

# Rename 'eddi' column
df_1 = df_1.rename({"eddi": "eddi_01wk"})
df_2 = df_2.rename({"eddi": "eddi_02wk"})
df_3 = df_3.rename({"eddi": "eddi_01mn"})

# Convert 'time' column from string to date format
df_1 = df_1.with_columns(pl.col("time").str.strptime(pl.Date, "%Y-%m-%d"))
df_2 = df_2.with_columns(pl.col("time").str.strptime(pl.Date, "%Y-%m-%d"))
df_3 = df_3.with_columns(pl.col("time").str.strptime(pl.Date, "%Y-%m-%d"))

# Merge the dataframes based on 'time', 'lat', and 'lon'
merged_df = df_1.join(df_2, on=["time", "lat", "lon"])
merged_df = merged_df.join(df_3, on=["time", "lat", "lon"])

# Display the merged dataframe
print(merged_df)
# Out:
# shape: (62_374_360, 6)
# ┌────────────┬───────┬──────┬───────────┬───────────┬───────────┐
# │ time       ┆ lat   ┆ lon  ┆ eddi_01wk ┆ eddi_02wk ┆ eddi_01mn │
# │ ---        ┆ ---   ┆ ---  ┆ ---       ┆ ---       ┆ ---       │
# │ date       ┆ f64   ┆ f64  ┆ f32       ┆ f32       ┆ f32       │
# ╞════════════╪═══════╪══════╪═══════════╪═══════════╪═══════════╡
# │ 1981-01-06 ┆ 22.0  ┆ 23.0 ┆ -0.353626 ┆ -0.17379  ┆ 0.05802   │
# │ 1981-01-06 ┆ 22.0  ┆ 23.5 ┆ -0.353626 ┆ -0.232805 ┆ -0.057442 │
# │ 1981-01-06 ┆ 22.0  ┆ 24.0 ┆ -0.353626 ┆ -0.232805 ┆ -0.115403 │
# │ 1981-01-06 ┆ 22.0  ┆ 24.5 ┆ -0.415945 ┆ -0.115403 ┆ -0.115403 │
# │ 1981-01-06 ┆ 22.0  ┆ 25.0 ┆ -0.614502 ┆ -0.115403 ┆ -0.17379  │
# │ …          ┆ …     ┆ …    ┆ …         ┆ …         ┆ …         │
# │ 2024-04-29 ┆ -11.5 ┆ 49.5 ┆ -999.0    ┆ -999.0    ┆ -999.0    │
# │ 2024-04-29 ┆ -11.5 ┆ 50.0 ┆ -999.0    ┆ -999.0    ┆ -999.0    │
# │ 2024-04-29 ┆ -11.5 ┆ 50.5 ┆ -999.0    ┆ -999.0    ┆ -999.0    │
# │ 2024-04-29 ┆ -11.5 ┆ 51.0 ┆ -999.0    ┆ -999.0    ┆ -999.0    │
# │ 2024-04-29 ┆ -11.5 ┆ 51.5 ┆ -999.0    ┆ -999.0    ┆ -999.0    │
# └────────────┴───────┴──────┴───────────┴───────────┴───────────┘

# %%
import polars as pl

# Define the paths to your Parquet files
parquet_files = [
    "/workspace/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/merged_eddi_data_01mn.parquet",
    "/workspace/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/merged_eddi_data_01wk.parquet",
    "/workspace/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/merged_eddi_data_02mn.parquet",
    "/workspace/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/merged_eddi_data_02wk.parquet",
    "/workspace/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/merged_eddi_data_03mn.parquet",
    "/workspace/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/merged_eddi_data_06mn.parquet",
    "/workspace/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/merged_eddi_data_09mn.parquet",
    "/workspace/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/merged_eddi_data_12_mn.parquet"
]

# Initialize an empty list to store the dataframes
dataframes = []

# Iterate over the Parquet files
for file_path in parquet_files:
    # Read the Parquet file
    df = pl.read_parquet(file_path)
    
    # Extract the time period from the file name
    time_period = file_path.split("_")[-1].split(".")[0]
    
    # Rename the 'eddi' column with the time period
    df = df.rename({"eddi": f"eddi_{time_period}"})
    
    # Check if 'time' column is already in Date format
    if df.dtypes[df.columns.index("time")] != pl.Date:
        # Convert 'time' column to Date format
        df = df.with_columns(pl.col("time").cast(pl.Date))
    
    # Append the dataframe to the list
    dataframes.append(df)

# Merge all the dataframes based on 'time', 'lat', and 'lon'
merged_df = dataframes[0]
for df in dataframes[1:]:
    merged_df = merged_df.join(df, on=["time", "lat", "lon"])
# Out:
# shape: (62_374_360, 11)
# ┌────────────┬───────┬──────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ time       ┆ lat   ┆ lon  ┆ eddi_01mn ┆ … ┆ eddi_03mn ┆ eddi_06mn ┆ eddi_09mn ┆ eddi_mn   │
# │ ---        ┆ ---   ┆ ---  ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ date       ┆ f64   ┆ f64  ┆ f32       ┆   ┆ f32       ┆ f32       ┆ f32       ┆ f32       │
# ╞════════════╪═══════╪══════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1981-01-01 ┆ 22.0  ┆ 23.0 ┆ 0.546651  ┆ … ┆ -0.545979 ┆ -0.479941 ┆ -0.115403 ┆ -0.115403 │
# │ 1981-01-01 ┆ 22.0  ┆ 23.5 ┆ 0.416576  ┆ … ┆ -0.545979 ┆ -0.479941 ┆ -0.115403 ┆ -0.057442 │
# │ 1981-01-01 ┆ 22.0  ┆ 24.0 ┆ 0.416576  ┆ … ┆ -0.545979 ┆ -0.614502 ┆ -0.115403 ┆ -0.115403 │
# │ 1981-01-01 ┆ 22.0  ┆ 24.5 ┆ 0.416576  ┆ … ┆ -0.479941 ┆ -0.686047 ┆ -0.115403 ┆ -0.17379  │
# │ 1981-01-01 ┆ 22.0  ┆ 25.0 ┆ 0.416576  ┆ … ┆ -0.415945 ┆ -0.686047 ┆ -0.232805 ┆ -0.17379  │
# │ …          ┆ …     ┆ …    ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 2024-04-29 ┆ -11.5 ┆ 49.5 ┆ -999.0    ┆ … ┆ -999.0    ┆ -999.0    ┆ -999.0    ┆ -999.0    │
# │ 2024-04-29 ┆ -11.5 ┆ 50.0 ┆ -999.0    ┆ … ┆ -999.0    ┆ -999.0    ┆ -999.0    ┆ -999.0    │
# │ 2024-04-29 ┆ -11.5 ┆ 50.5 ┆ -999.0    ┆ … ┆ -999.0    ┆ -999.0    ┆ -999.0    ┆ -999.0    │
# │ 2024-04-29 ┆ -11.5 ┆ 51.0 ┆ -999.0    ┆ … ┆ -999.0    ┆ -999.0    ┆ -999.0    ┆ -999.0    │
# │ 2024-04-29 ┆ -11.5 ┆ 51.5 ┆ -999.0    ┆ … ┆ -999.0    ┆ -999.0    ┆ -999.0    ┆ -999.0    │
# └────────────┴───────┴──────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
import polars as pl
from typing import List

def merge_parquet_files(parquet_files: List[str]) -> pl.DataFrame:
    """
    Merge multiple Parquet files into a single DataFrame.

    Args:
        parquet_files (List[str]): List of file paths to the Parquet files.

    Returns:
        pl.DataFrame: Merged DataFrame containing data from all the Parquet files.
    """
    # Initialize an empty list to store the dataframes
    dataframes = []

    # Iterate over the Parquet files
    for file_path in parquet_files:
        try:
            # Read the Parquet file
            df = pl.read_parquet(file_path)
            
            # Extract the time period from the file name
            time_period = file_path.split("_")[-1].split(".")[0]
            
            # Rename the 'eddi' column with the time period
            df = df.rename({"eddi": f"eddi_{time_period}"})
            
            # Check if 'time' column is already in Date format
            if df.dtypes[df.columns.index("time")] != pl.Date:
                # Convert 'time' column to Date format
                df = df.with_columns(pl.col("time").cast(pl.Date))
            
            # Append the dataframe to the list
            dataframes.append(df)
        except Exception as e:
            print(f"Error processing file: {file_path}")
            print(f"Error message: {str(e)}")
            continue

    # Check if any dataframes were successfully loaded
    if not dataframes:
        raise ValueError("No valid dataframes found in the provided Parquet files.")

    # Merge all the dataframes based on 'time', 'lat', and 'lon'
    merged_df = dataframes[0]
    for df in dataframes[1:]:
        try:
            merged_df = merged_df.join(df, on=["time", "lat", "lon"])
        except Exception as e:
            print(f"Error merging dataframe: {str(e)}")
            raise

    return merged_df

# %%
# Define the paths to your Parquet files
parquet_files = [
    "/workspace/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/merged_eddi_data_01mn.parquet",
    "/workspace/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/merged_eddi_data_01wk.parquet",
    "/workspace/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/merged_eddi_data_02mn.parquet",
    "/workspace/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/merged_eddi_data_02wk.parquet",
    "/workspace/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/merged_eddi_data_03mn.parquet",
    "/workspace/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/merged_eddi_data_06mn.parquet",
    "/workspace/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/merged_eddi_data_09mn.parquet",
    "/workspace/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/merged_eddi_data_12mn.parquet"
]

merged_df = merge_parquet_files(parquet_files)

# %%
merged_df
# Out:
# shape: (62_374_360, 11)
# ┌────────────┬───────┬──────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ time       ┆ lat   ┆ lon  ┆ eddi_01mn ┆ … ┆ eddi_03mn ┆ eddi_06mn ┆ eddi_09mn ┆ eddi_12mn │
# │ ---        ┆ ---   ┆ ---  ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ date       ┆ f64   ┆ f64  ┆ f32       ┆   ┆ f32       ┆ f32       ┆ f32       ┆ f32       │
# ╞════════════╪═══════╪══════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1981-01-01 ┆ 22.0  ┆ 23.0 ┆ 0.546651  ┆ … ┆ -0.545979 ┆ -0.479941 ┆ -0.115403 ┆ -0.115403 │
# │ 1981-01-01 ┆ 22.0  ┆ 23.5 ┆ 0.416576  ┆ … ┆ -0.545979 ┆ -0.479941 ┆ -0.115403 ┆ -0.057442 │
# │ 1981-01-01 ┆ 22.0  ┆ 24.0 ┆ 0.416576  ┆ … ┆ -0.545979 ┆ -0.614502 ┆ -0.115403 ┆ -0.115403 │
# │ 1981-01-01 ┆ 22.0  ┆ 24.5 ┆ 0.416576  ┆ … ┆ -0.479941 ┆ -0.686047 ┆ -0.115403 ┆ -0.17379  │
# │ 1981-01-01 ┆ 22.0  ┆ 25.0 ┆ 0.416576  ┆ … ┆ -0.415945 ┆ -0.686047 ┆ -0.232805 ┆ -0.17379  │
# │ …          ┆ …     ┆ …    ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 2024-04-29 ┆ -11.5 ┆ 49.5 ┆ -999.0    ┆ … ┆ -999.0    ┆ -999.0    ┆ -999.0    ┆ -999.0    │
# │ 2024-04-29 ┆ -11.5 ┆ 50.0 ┆ -999.0    ┆ … ┆ -999.0    ┆ -999.0    ┆ -999.0    ┆ -999.0    │
# │ 2024-04-29 ┆ -11.5 ┆ 50.5 ┆ -999.0    ┆ … ┆ -999.0    ┆ -999.0    ┆ -999.0    ┆ -999.0    │
# │ 2024-04-29 ┆ -11.5 ┆ 51.0 ┆ -999.0    ┆ … ┆ -999.0    ┆ -999.0    ┆ -999.0    ┆ -999.0    │
# │ 2024-04-29 ┆ -11.5 ┆ 51.5 ┆ -999.0    ┆ … ┆ -999.0    ┆ -999.0    ┆ -999.0    ┆ -999.0    │
# └────────────┴───────┴──────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
# import polars as pl
# # Define the path to your Parquet file
# parquet_file_path = "/workspace/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/merged_eddi_data_02wk.parquet"
# # parquet_file_path = "/workspace/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/merged_eddi_data.parquet"


# # Use Polars to read the Parquet file
# df = pl.read_parquet(parquet_file_path)
# df

# %%
output_file_path = '/workspace/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/merged_eddi_data.parquet'

# %%
merged_df.write_parquet(output_file_path)

# %%
def regrid_polars_df(df, start_lat=-12.0, start_lon=23.125, new_lat_res=0.5, new_lon_res=0.625):
    """
    Regrids a Polars DataFrame with latitude and longitude to a common specified grid, starting from specified latitude and longitude.

    Parameters:
    - df (pl.DataFrame): Polars DataFrame to be regridded.
    - start_lat (float): Starting latitude for the grid.
    - start_lon (float): Starting longitude for the grid.
    - new_lat_res (float): The new resolution for latitude.
    - new_lon_res (float): The new resolution for longitude.

    Returns:
    - pl.DataFrame: A DataFrame containing the regridded data.

    Example of usage:
    regridded_df = regrid_polars_df(polars_df)
    """
    # Calculate global min and max of latitude and longitude
    lat_min = df.select(pl.min('lat')).to_numpy().item()
    lat_max = df.select(pl.max('lat')).to_numpy().item()
    lon_min = df.select(pl.min('lon')).to_numpy().item()
    lon_max = df.select(pl.max('lon')).to_numpy().item()

    # Adjust the start points if they are outside the current data range
    start_lat = max(lat_min, start_lat)
    start_lon = max(lon_min, start_lon)

    # Create common latitude and longitude grids starting from the specified points
    common_lat = np.arange(start_lat, lat_max + new_lat_res, new_lat_res)
    common_lon = np.arange(start_lon, lon_max + new_lon_res, new_lon_res)

    # Function to find nearest grid point
    def find_nearest(array, value):
        idx = (np.abs(array - value)).argmin()
        return array[idx]

    # Map each lat and lon in the DataFrame to the nearest grid point
    df = df.with_columns([
        df['lat'].map_elements(lambda x: find_nearest(common_lat, x), return_dtype=float).alias('new_lat'),
        df['lon'].map_elements(lambda x: find_nearest(common_lon, x), return_dtype=float).alias('new_lon')
    ]).drop(['lat', 'lon']).rename({'new_lat': 'lat', 'new_lon': 'lon'})

    # Optional: Aggregate data if necessary
    df = df.group_by(['time', 'lat', 'lon']).agg(pl.col('eddi').mean().alias('eddi'))

    # Sort by time, latitude, and longitude for better organization
    df = df.sort(['time', 'lat', 'lon'])

    return df

# Usage example (assuming df is your DataFrame loaded with data)
regridded_df = regrid_polars_df(eddi_clean_df)

# %%
regridded_df
# Out:
# shape: (21_086_019, 4)
# ┌─────────────────────┬───────┬────────┬───────────┐
# │ time                ┆ lat   ┆ lon    ┆ eddi      │
# │ ---                 ┆ ---   ┆ ---    ┆ ---       │
# │ datetime[μs]        ┆ f64   ┆ f64    ┆ f32       │
# ╞═════════════════════╪═══════╪════════╪═══════════╡
# │ 2001-01-01 00:00:00 ┆ -12.0 ┆ 23.125 ┆ -0.761296 │
# │ 2001-01-01 00:00:00 ┆ -12.0 ┆ 23.75  ┆ -0.88392  │
# │ 2001-01-01 00:00:00 ┆ -12.0 ┆ 24.375 ┆ -0.926714 │
# │ 2001-01-01 00:00:00 ┆ -12.0 ┆ 25.0   ┆ -1.019687 │
# │ 2001-01-01 00:00:00 ┆ -12.0 ┆ 25.625 ┆ -1.019687 │
# │ …                   ┆ …     ┆ …      ┆ …         │
# │ 2024-04-13 00:00:00 ┆ 21.5  ┆ 38.75  ┆ 0.567209  │
# │ 2024-04-13 00:00:00 ┆ 21.5  ┆ 39.375 ┆ 0.437543  │
# │ 2024-04-13 00:00:00 ┆ 21.5  ┆ 40.0   ┆ 0.199132  │
# │ 2024-04-13 00:00:00 ┆ 21.5  ┆ 43.125 ┆ -0.500068 │
# │ 2024-04-13 00:00:00 ┆ 21.5  ┆ 48.75  ┆ -0.436921 │
# └─────────────────────┴───────┴────────┴───────────┘

# %%
regridded_df.write_parquet("/workspace/ml-drought-forecasting/ml-modeling-pipeline/data/01_raw/eddi.parquet")
