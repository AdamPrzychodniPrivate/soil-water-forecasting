# %%
import re
import os
import shutil
import requests
import polars as pl
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor
import rasterio
from affine import Affine
import numpy as np

# %%
def fetch_file_links(year_url, file_type):
    try:
        response = requests.get(year_url)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        links = soup.find_all('a')
        file_links = [year_url + link['href'] for link in links if link['href'].endswith('.asc')]
        filtered_links = [link for link in file_links if file_type in link]
        return filtered_links
    except requests.exceptions.RequestException as e:
        print(f"Failed to fetch file links. Error: {e}")
        return []

def download_file(url, destination_folder):
    filename = url.split("/")[-1]
    destination_path = os.path.join(destination_folder, filename)
    try:
        response = requests.get(url)
        response.raise_for_status()
        with open(destination_path, 'wb') as f:
            f.write(response.content)
        print(f"File downloaded successfully: {filename}")
    except requests.exceptions.RequestException as e:
        print(f"Failed to download the file: {filename}. Error: {e}")

def append_and_process_files(source_dir, transform, row_start, row_end, col_start, col_end):
    master_df = pl.DataFrame()
    for filename in os.listdir(source_dir):
        if filename.endswith('.asc'):
            file_path = os.path.join(source_dir, filename)
            with rasterio.open(file_path) as src:
                data = src.read(1)  # Read the first band
                filtered_data = data[row_start:row_end, col_start:col_end]
            df = create_polars_dataframe(file_path, filtered_data, row_start, row_end, col_start, col_end, transform)
            master_df = master_df.vstack(df) if not master_df.is_empty() else df
    return master_df


def create_polars_dataframe(file_name: str, data: np.ndarray, row_start: int, row_end: int, col_start: int, col_end: int, transform: Affine):
    """
    Creates a Polars DataFrame from filtered raster data with columns for time, latitude, longitude, and EDDI values.

    Parameters:
    - file_name (str): The name of the file, used to extract the time information.
    - data (numpy.ndarray): The filtered raster data array.
    - row_start (int): The starting index for rows of the filtered data.
    - row_end (int): The ending index for rows of the filtered data.
    - col_start (int): The starting index for columns of the filtered data.
    - col_end (int): The ending index for columns of the filtered data.
    - transform (Affine): The affine transformation used to convert indices to geographic coordinates.

    Returns:
    - pl.DataFrame: A Polars DataFrame with columns for time, latitude, longitude, and EDDI values.
    """
    # Extract the date from the file name using regular expressions
    date_match = re.search(r'\d{8}', file_name)
    if date_match:
        date = date_match.group(0)
        # Transform the date to 'yyyy-mm-dd' format
        formatted_date = f"{date[:4]}-{date[4:6]}-{date[6:]}"
    else:
        raise ValueError("Date not found in file name.")

    # Generate latitude and longitude arrays
    lon_arr = []
    lat_arr = []
    for row in range(row_start, row_end):
        for col in range(col_start, col_end):
            lon, lat = transform * (col, row)
            lon_arr.append(lon)
            lat_arr.append(lat)

    # Flatten the data array to match the latitude and longitude arrays
    eddi_values = data.flatten()

    # Create a Polars DataFrame
    df = pl.DataFrame({
        "time": [formatted_date] * len(eddi_values),
        "lat": lat_arr,
        "lon": lon_arr,
        "eddi": eddi_values
    })

    return df


from rasterio.transform import Affine
import numpy as np

def geographic_to_index(lon, lat, transform):
    """
    Convert geographic coordinates to raster indices.

    Parameters:
    - lon (float): The longitude to convert.
    - lat (float): The latitude to convert.
    - transform (Affine): The affine transform associated with the raster, defining how geographic coordinates are transformed into raster indices.

    Returns:
    - (int, int): The zero-based column index and row index corresponding to the given longitude and latitude.
    """
    col, row = ~transform * (lon, lat)
    return int(col), int(row)

def download_and_process_raster_data(base_url, start_year, end_year, file_type, destination_folder):
    # Define the affine transform for a raster where each pixel represents a 0.5x0.5 degree area
    transform = Affine(0.5, 0.0, -180, 0.0, -0.5, 90)

    # Define geographic bounds and calculate index ranges
    lat_range = (-12, 22)  # South to North
    lon_range = (23, 52)  # West to East
    col_start, row_end = geographic_to_index(lon_range[0], lat_range[0], transform)
    col_end, row_start = geographic_to_index(lon_range[1], lat_range[1], transform)

    for year in range(start_year, end_year + 1):
        year_url = f"{base_url}{year}/"
        year_destination_folder = os.path.join(destination_folder, str(year))
        
        if not os.path.exists(year_destination_folder):
            os.makedirs(year_destination_folder)
        
        file_links = fetch_file_links(year_url, file_type)
        with ThreadPoolExecutor(max_workers=8) as executor:
            executor.map(lambda url: download_file(url, year_destination_folder), file_links)
        
        # Process and append raster data to a Polars DataFrame
        master_df = append_and_process_files(year_destination_folder, transform, row_start, row_end, col_start, col_end)
        
        # Save the DataFrame as a Parquet file
        parquet_path = os.path.join(destination_folder, f"EDDI_{file_type}_{year}.parquet")
        master_df.write_parquet(parquet_path)
        print(f"Data for year {year} processed and saved as Parquet at {parquet_path}.")
        
        shutil.rmtree(year_destination_folder)  # Optional: remove the directory after processing

# Example usage
base_url = "https://downloads.psl.noaa.gov/Projects/EDDI/global_archive/NCEP/"
destination_folder = "/workspace/soil-ml-modeling-pipeline/ml-modeling-pipeline/data/01_raw/eddi"
start_year = 2011
end_year = 2024
file_type = "12mn"
download_and_process_raster_data(base_url, start_year, end_year, file_type, destination_folder)
# Out:
# File downloaded successfully: EDDI_12mn_20110108.asc
# File downloaded successfully: EDDI_12mn_20110105.asc
# File downloaded successfully: EDDI_12mn_20110102.asc
# File downloaded successfully: EDDI_12mn_20110101.asc
# File downloaded successfully: EDDI_12mn_20110106.asc
# File downloaded successfully: EDDI_12mn_20110103.asc
# File downloaded successfully: EDDI_12mn_20110107.asc
# File downloaded successfully: EDDI_12mn_20110104.asc
# File downloaded successfully: EDDI_12mn_20110109.asc
# File downloaded successfully: EDDI_12mn_20110110.asc
# File downloaded successfully: EDDI_12mn_20110113.asc
# File downloaded successfully: EDDI_12mn_20110112.asc
# File downloaded successfully: EDDI_12mn_20110111.asc
# File downloaded successfully: EDDI_12mn_20110114.asc
# File downloaded successfully: EDDI_12mn_20110115.asc
# File downloaded successfully: EDDI_12mn_20110119.asc
# File downloaded successfully: EDDI_12mn_20110120.asc
# File downloaded successfully: EDDI_12mn_20110121.asc
# File downloaded successfully: EDDI_12mn_20110118.asc
# File downloaded successfully: EDDI_12mn_20110122.asc
# File downloaded successfully: EDDI_12mn_20110123.asc
# File downloaded successfully: EDDI_12mn_20110117.asc
# File downloaded successfully: EDDI_12mn_20110124.asc
# File downloaded successfully: EDDI_12mn_20110125.asc
# File downloaded successfully: EDDI_12mn_20110126.asc
# File downloaded successfully: EDDI_12mn_20110128.asc
# File downloaded successfully: EDDI_12mn_20110127.asc
# File downloaded successfully: EDDI_12mn_20110129.asc
# File downloaded successfully: EDDI_12mn_20110131.asc
# File downloaded successfully: EDDI_12mn_20110202.asc
# File downloaded successfully: EDDI_12mn_20110203.asc
# File downloaded successfully: EDDI_12mn_20110204.asc
# File downloaded successfully: EDDI_12mn_20110205.asc
# File downloaded successfully: EDDI_12mn_20110130.asc
# File downloaded successfully: EDDI_12mn_20110116.asc
# File downloaded successfully: EDDI_12mn_20110206.asc
# File downloaded successfully: EDDI_12mn_20110209.asc
# File downloaded successfully: EDDI_12mn_20110207.asc
# File downloaded successfully: EDDI_12mn_20110210.asc
# File downloaded successfully: EDDI_12mn_20110208.asc
# File downloaded successfully: EDDI_12mn_20110212.asc
# File downloaded successfully: EDDI_12mn_20110211.asc
# File downloaded successfully: EDDI_12mn_20110213.asc
# File downloaded successfully: EDDI_12mn_20110214.asc
# File downloaded successfully: EDDI_12mn_20110215.asc
# File downloaded successfully: EDDI_12mn_20110216.asc
# File downloaded successfully: EDDI_12mn_20110218.asc
# File downloaded successfully: EDDI_12mn_20110217.asc
# File downloaded successfully: EDDI_12mn_20110219.asc
# File downloaded successfully: EDDI_12mn_20110220.asc
# File downloaded successfully: EDDI_12mn_20110221.asc
# File downloaded successfully: EDDI_12mn_20110222.asc
# File downloaded successfully: EDDI_12mn_20110224.asc
# File downloaded successfully: EDDI_12mn_20110223.asc
# File downloaded successfully: EDDI_12mn_20110227.asc
# File downloaded successfully: EDDI_12mn_20110225.asc
# File downloaded successfully: EDDI_12mn_20110301.asc
# File downloaded successfully: EDDI_12mn_20110226.asc
# File downloaded successfully: EDDI_12mn_20110302.asc
# File downloaded successfully: EDDI_12mn_20110201.asc
# File downloaded successfully: EDDI_12mn_20110303.asc
# File downloaded successfully: EDDI_12mn_20110304.asc
# File downloaded successfully: EDDI_12mn_20110305.asc
# File downloaded successfully: EDDI_12mn_20110307.asc
# File downloaded successfully: EDDI_12mn_20110308.asc
# File downloaded successfully: EDDI_12mn_20110309.asc
# File downloaded successfully: EDDI_12mn_20110311.asc
# File downloaded successfully: EDDI_12mn_20110312.asc
# File downloaded successfully: EDDI_12mn_20110313.asc
# File downloaded successfully: EDDI_12mn_20110306.asc
# File downloaded successfully: EDDI_12mn_20110310.asc
# File downloaded successfully: EDDI_12mn_20110314.asc
# File downloaded successfully: EDDI_12mn_20110315.asc
# File downloaded successfully: EDDI_12mn_20110316.asc
# File downloaded successfully: EDDI_12mn_20110317.asc
# File downloaded successfully: EDDI_12mn_20110318.asc
# File downloaded successfully: EDDI_12mn_20110319.asc
# File downloaded successfully: EDDI_12mn_20110321.asc
# File downloaded successfully: EDDI_12mn_20110320.asc
# File downloaded successfully: EDDI_12mn_20110322.asc
# File downloaded successfully: EDDI_12mn_20110228.asc
# File downloaded successfully: EDDI_12mn_20110325.asc
# File downloaded successfully: EDDI_12mn_20110327.asc
# File downloaded successfully: EDDI_12mn_20110324.asc
# File downloaded successfully: EDDI_12mn_20110326.asc
# File downloaded successfully: EDDI_12mn_20110328.asc
# File downloaded successfully: EDDI_12mn_20110329.asc
# File downloaded successfully: EDDI_12mn_20110330.asc
# File downloaded successfully: EDDI_12mn_20110331.asc
# File downloaded successfully: EDDI_12mn_20110402.asc
# File downloaded successfully: EDDI_12mn_20110403.asc
# File downloaded successfully: EDDI_12mn_20110404.asc
# File downloaded successfully: EDDI_12mn_20110401.asc
# File downloaded successfully: EDDI_12mn_20110323.asc
# File downloaded successfully: EDDI_12mn_20110405.asc
# File downloaded successfully: EDDI_12mn_20110406.asc
# File downloaded successfully: EDDI_12mn_20110407.asc
# File downloaded successfully: EDDI_12mn_20110408.asc
# File downloaded successfully: EDDI_12mn_20110409.asc
# File downloaded successfully: EDDI_12mn_20110411.asc
# File downloaded successfully: EDDI_12mn_20110413.asc
# File downloaded successfully: EDDI_12mn_20110414.asc
# File downloaded successfully: EDDI_12mn_20110412.asc
# File downloaded successfully: EDDI_12mn_20110416.asc
# File downloaded successfully: EDDI_12mn_20110415.asc
# File downloaded successfully: EDDI_12mn_20110410.asc
# File downloaded successfully: EDDI_12mn_20110417.asc
# File downloaded successfully: EDDI_12mn_20110418.asc
# File downloaded successfully: EDDI_12mn_20110420.asc
# File downloaded successfully: EDDI_12mn_20110421.asc
# File downloaded successfully: EDDI_12mn_20110419.asc
# File downloaded successfully: EDDI_12mn_20110422.asc
# File downloaded successfully: EDDI_12mn_20110423.asc
# File downloaded successfully: EDDI_12mn_20110425.asc
# File downloaded successfully: EDDI_12mn_20110426.asc
# File downloaded successfully: EDDI_12mn_20110427.asc
# File downloaded successfully: EDDI_12mn_20110424.asc
# File downloaded successfully: EDDI_12mn_20110429.asc
# File downloaded successfully: EDDI_12mn_20110430.asc
# File downloaded successfully: EDDI_12mn_20110502.asc
# File downloaded successfully: EDDI_12mn_20110428.asc
# File downloaded successfully: EDDI_12mn_20110503.asc
# File downloaded successfully: EDDI_12mn_20110504.asc
# File downloaded successfully: EDDI_12mn_20110505.asc
# File downloaded successfully: EDDI_12mn_20110506.asc
# File downloaded successfully: EDDI_12mn_20110509.asc
# File downloaded successfully: EDDI_12mn_20110508.asc
# File downloaded successfully: EDDI_12mn_20110510.asc
# File downloaded successfully: EDDI_12mn_20110512.asc
# File downloaded successfully: EDDI_12mn_20110511.asc
# File downloaded successfully: EDDI_12mn_20110513.asc
# File downloaded successfully: EDDI_12mn_20110514.asc
# File downloaded successfully: EDDI_12mn_20110515.asc
# File downloaded successfully: EDDI_12mn_20110516.asc
# File downloaded successfully: EDDI_12mn_20110517.asc
# File downloaded successfully: EDDI_12mn_20110518.asc
# File downloaded successfully: EDDI_12mn_20110519.asc
# File downloaded successfully: EDDI_12mn_20110520.asc
# File downloaded successfully: EDDI_12mn_20110521.asc
# File downloaded successfully: EDDI_12mn_20110522.asc
# File downloaded successfully: EDDI_12mn_20110523.asc
# File downloaded successfully: EDDI_12mn_20110525.asc
# File downloaded successfully: EDDI_12mn_20110529.asc
# File downloaded successfully: EDDI_12mn_20110526.asc
# File downloaded successfully: EDDI_12mn_20110501.asc
# File downloaded successfully: EDDI_12mn_20110530.asc
# File downloaded successfully: EDDI_12mn_20110531.asc
# File downloaded successfully: EDDI_12mn_20110528.asc
# File downloaded successfully: EDDI_12mn_20110507.asc
# File downloaded successfully: EDDI_12mn_20110601.asc
# File downloaded successfully: EDDI_12mn_20110602.asc
# File downloaded successfully: EDDI_12mn_20110524.asc
# File downloaded successfully: EDDI_12mn_20110603.asc
# File downloaded successfully: EDDI_12mn_20110606.asc
# File downloaded successfully: EDDI_12mn_20110605.asc
# File downloaded successfully: EDDI_12mn_20110604.asc
# File downloaded successfully: EDDI_12mn_20110607.asc
# File downloaded successfully: EDDI_12mn_20110610.asc
# File downloaded successfully: EDDI_12mn_20110609.asc
# File downloaded successfully: EDDI_12mn_20110612.asc
# File downloaded successfully: EDDI_12mn_20110527.asc
# File downloaded successfully: EDDI_12mn_20110611.asc
# File downloaded successfully: EDDI_12mn_20110613.asc
# File downloaded successfully: EDDI_12mn_20110614.asc
# File downloaded successfully: EDDI_12mn_20110615.asc
# File downloaded successfully: EDDI_12mn_20110616.asc
# File downloaded successfully: EDDI_12mn_20110608.asc
# File downloaded successfully: EDDI_12mn_20110617.asc
# File downloaded successfully: EDDI_12mn_20110618.asc
# File downloaded successfully: EDDI_12mn_20110620.asc
# File downloaded successfully: EDDI_12mn_20110619.asc
# File downloaded successfully: EDDI_12mn_20110621.asc
# File downloaded successfully: EDDI_12mn_20110622.asc
# File downloaded successfully: EDDI_12mn_20110624.asc
# File downloaded successfully: EDDI_12mn_20110623.asc
# File downloaded successfully: EDDI_12mn_20110625.asc
# File downloaded successfully: EDDI_12mn_20110626.asc
# File downloaded successfully: EDDI_12mn_20110627.asc
# File downloaded successfully: EDDI_12mn_20110629.asc
# File downloaded successfully: EDDI_12mn_20110628.asc
# File downloaded successfully: EDDI_12mn_20110630.asc
# File downloaded successfully: EDDI_12mn_20110702.asc
# File downloaded successfully: EDDI_12mn_20110701.asc
# File downloaded successfully: EDDI_12mn_20110703.asc
# File downloaded successfully: EDDI_12mn_20110704.asc
# File downloaded successfully: EDDI_12mn_20110705.asc
# File downloaded successfully: EDDI_12mn_20110706.asc
# File downloaded successfully: EDDI_12mn_20110708.asc
# File downloaded successfully: EDDI_12mn_20110709.asc
# File downloaded successfully: EDDI_12mn_20110710.asc
# File downloaded successfully: EDDI_12mn_20110711.asc
# File downloaded successfully: EDDI_12mn_20110712.asc
# File downloaded successfully: EDDI_12mn_20110713.asc
# File downloaded successfully: EDDI_12mn_20110707.asc
# File downloaded successfully: EDDI_12mn_20110714.asc
# File downloaded successfully: EDDI_12mn_20110715.asc
# File downloaded successfully: EDDI_12mn_20110716.asc
# File downloaded successfully: EDDI_12mn_20110717.asc
# File downloaded successfully: EDDI_12mn_20110718.asc
# File downloaded successfully: EDDI_12mn_20110720.asc
# File downloaded successfully: EDDI_12mn_20110721.asc
# File downloaded successfully: EDDI_12mn_20110719.asc
# File downloaded successfully: EDDI_12mn_20110722.asc
# File downloaded successfully: EDDI_12mn_20110723.asc
# File downloaded successfully: EDDI_12mn_20110724.asc
# File downloaded successfully: EDDI_12mn_20110726.asc
# File downloaded successfully: EDDI_12mn_20110727.asc
# File downloaded successfully: EDDI_12mn_20110728.asc
# File downloaded successfully: EDDI_12mn_20110731.asc
# File downloaded successfully: EDDI_12mn_20110725.asc
# File downloaded successfully: EDDI_12mn_20110801.asc
# File downloaded successfully: EDDI_12mn_20110802.asc
# File downloaded successfully: EDDI_12mn_20110803.asc
# File downloaded successfully: EDDI_12mn_20110804.asc
# File downloaded successfully: EDDI_12mn_20110806.asc
# File downloaded successfully: EDDI_12mn_20110805.asc
# File downloaded successfully: EDDI_12mn_20110729.asc
# File downloaded successfully: EDDI_12mn_20110730.asc
# File downloaded successfully: EDDI_12mn_20110808.asc
# File downloaded successfully: EDDI_12mn_20110807.asc
# File downloaded successfully: EDDI_12mn_20110809.asc
# File downloaded successfully: EDDI_12mn_20110810.asc
# File downloaded successfully: EDDI_12mn_20110811.asc
# File downloaded successfully: EDDI_12mn_20110813.asc
# File downloaded successfully: EDDI_12mn_20110814.asc
# File downloaded successfully: EDDI_12mn_20110815.asc
# File downloaded successfully: EDDI_12mn_20110817.asc
# File downloaded successfully: EDDI_12mn_20110816.asc
# File downloaded successfully: EDDI_12mn_20110819.asc
# File downloaded successfully: EDDI_12mn_20110812.asc
# File downloaded successfully: EDDI_12mn_20110818.asc
# File downloaded successfully: EDDI_12mn_20110822.asc
# File downloaded successfully: EDDI_12mn_20110821.asc
# File downloaded successfully: EDDI_12mn_20110823.asc
# File downloaded successfully: EDDI_12mn_20110825.asc
# File downloaded successfully: EDDI_12mn_20110827.asc
# File downloaded successfully: EDDI_12mn_20110826.asc
# File downloaded successfully: EDDI_12mn_20110829.asc
# File downloaded successfully: EDDI_12mn_20110820.asc
# File downloaded successfully: EDDI_12mn_20110830.asc
# File downloaded successfully: EDDI_12mn_20110824.asc
# File downloaded successfully: EDDI_12mn_20110828.asc
# File downloaded successfully: EDDI_12mn_20110901.asc
# File downloaded successfully: EDDI_12mn_20110831.asc
# File downloaded successfully: EDDI_12mn_20110903.asc
# File downloaded successfully: EDDI_12mn_20110905.asc
# File downloaded successfully: EDDI_12mn_20110906.asc
# File downloaded successfully: EDDI_12mn_20110902.asc
# File downloaded successfully: EDDI_12mn_20110907.asc
# File downloaded successfully: EDDI_12mn_20110909.asc
# File downloaded successfully: EDDI_12mn_20110910.asc
# File downloaded successfully: EDDI_12mn_20110912.asc
# File downloaded successfully: EDDI_12mn_20110904.asc
# File downloaded successfully: EDDI_12mn_20110914.asc
# File downloaded successfully: EDDI_12mn_20110913.asc
# File downloaded successfully: EDDI_12mn_20110908.asc
# File downloaded successfully: EDDI_12mn_20110915.asc
# File downloaded successfully: EDDI_12mn_20110911.asc
# File downloaded successfully: EDDI_12mn_20110916.asc
# File downloaded successfully: EDDI_12mn_20110917.asc
# File downloaded successfully: EDDI_12mn_20110919.asc
# File downloaded successfully: EDDI_12mn_20110920.asc
# File downloaded successfully: EDDI_12mn_20110918.asc
# File downloaded successfully: EDDI_12mn_20110923.asc
# File downloaded successfully: EDDI_12mn_20110924.asc
# File downloaded successfully: EDDI_12mn_20110926.asc
# File downloaded successfully: EDDI_12mn_20110925.asc
# File downloaded successfully: EDDI_12mn_20110927.asc
# File downloaded successfully: EDDI_12mn_20110928.asc
# File downloaded successfully: EDDI_12mn_20110922.asc
# File downloaded successfully: EDDI_12mn_20110929.asc
# File downloaded successfully: EDDI_12mn_20110930.asc
# File downloaded successfully: EDDI_12mn_20111001.asc
# File downloaded successfully: EDDI_12mn_20111003.asc
# File downloaded successfully: EDDI_12mn_20111002.asc
# File downloaded successfully: EDDI_12mn_20111004.asc
# File downloaded successfully: EDDI_12mn_20111005.asc
# File downloaded successfully: EDDI_12mn_20111006.asc
# File downloaded successfully: EDDI_12mn_20111007.asc
# File downloaded successfully: EDDI_12mn_20111008.asc
# File downloaded successfully: EDDI_12mn_20111010.asc
# File downloaded successfully: EDDI_12mn_20111011.asc
# File downloaded successfully: EDDI_12mn_20111012.asc
# File downloaded successfully: EDDI_12mn_20111013.asc
# File downloaded successfully: EDDI_12mn_20111014.asc
# File downloaded successfully: EDDI_12mn_20111009.asc
# File downloaded successfully: EDDI_12mn_20111016.asc
# File downloaded successfully: EDDI_12mn_20111017.asc
# File downloaded successfully: EDDI_12mn_20111018.asc
# File downloaded successfully: EDDI_12mn_20111015.asc
# File downloaded successfully: EDDI_12mn_20111019.asc
# File downloaded successfully: EDDI_12mn_20111020.asc
# File downloaded successfully: EDDI_12mn_20111021.asc
# File downloaded successfully: EDDI_12mn_20111022.asc
# File downloaded successfully: EDDI_12mn_20111023.asc
# File downloaded successfully: EDDI_12mn_20111025.asc
# File downloaded successfully: EDDI_12mn_20111024.asc
# File downloaded successfully: EDDI_12mn_20111027.asc
# File downloaded successfully: EDDI_12mn_20111026.asc
# File downloaded successfully: EDDI_12mn_20111028.asc
# File downloaded successfully: EDDI_12mn_20111029.asc
# File downloaded successfully: EDDI_12mn_20111030.asc
# File downloaded successfully: EDDI_12mn_20111031.asc
# File downloaded successfully: EDDI_12mn_20111101.asc
# File downloaded successfully: EDDI_12mn_20111102.asc
# File downloaded successfully: EDDI_12mn_20111103.asc
# File downloaded successfully: EDDI_12mn_20111105.asc
# File downloaded successfully: EDDI_12mn_20111106.asc
# File downloaded successfully: EDDI_12mn_20111107.asc
# File downloaded successfully: EDDI_12mn_20111109.asc
# File downloaded successfully: EDDI_12mn_20111110.asc
# File downloaded successfully: EDDI_12mn_20111108.asc
# File downloaded successfully: EDDI_12mn_20111104.asc
# File downloaded successfully: EDDI_12mn_20110921.asc
# File downloaded successfully: EDDI_12mn_20111111.asc
# File downloaded successfully: EDDI_12mn_20111113.asc
# File downloaded successfully: EDDI_12mn_20111112.asc
# File downloaded successfully: EDDI_12mn_20111115.asc
# File downloaded successfully: EDDI_12mn_20111116.asc
# File downloaded successfully: EDDI_12mn_20111117.asc
# File downloaded successfully: EDDI_12mn_20111118.asc
# File downloaded successfully: EDDI_12mn_20111120.asc
# File downloaded successfully: EDDI_12mn_20111122.asc
# File downloaded successfully: EDDI_12mn_20111119.asc
# File downloaded successfully: EDDI_12mn_20111125.asc
# File downloaded successfully: EDDI_12mn_20111124.asc
# File downloaded successfully: EDDI_12mn_20111126.asc
# File downloaded successfully: EDDI_12mn_20111128.asc
# File downloaded successfully: EDDI_12mn_20111129.asc
# File downloaded successfully: EDDI_12mn_20111130.asc
# File downloaded successfully: EDDI_12mn_20111201.asc
# File downloaded successfully: EDDI_12mn_20111203.asc
# File downloaded successfully: EDDI_12mn_20111114.asc
# File downloaded successfully: EDDI_12mn_20111204.asc
# File downloaded successfully: EDDI_12mn_20111205.asc
# File downloaded successfully: EDDI_12mn_20111127.asc
# File downloaded successfully: EDDI_12mn_20111206.asc
# File downloaded successfully: EDDI_12mn_20111207.asc
# File downloaded successfully: EDDI_12mn_20111121.asc
# File downloaded successfully: EDDI_12mn_20111208.asc
# File downloaded successfully: EDDI_12mn_20111209.asc
# File downloaded successfully: EDDI_12mn_20111210.asc
# File downloaded successfully: EDDI_12mn_20111212.asc
# File downloaded successfully: EDDI_12mn_20111211.asc
# File downloaded successfully: EDDI_12mn_20111213.asc
# File downloaded successfully: EDDI_12mn_20111214.asc
# File downloaded successfully: EDDI_12mn_20111216.asc
# File downloaded successfully: EDDI_12mn_20111215.asc
# File downloaded successfully: EDDI_12mn_20111218.asc
# File downloaded successfully: EDDI_12mn_20111220.asc
# File downloaded successfully: EDDI_12mn_20111221.asc
# File downloaded successfully: EDDI_12mn_20111222.asc
# File downloaded successfully: EDDI_12mn_20111123.asc
# File downloaded successfully: EDDI_12mn_20111219.asc
# File downloaded successfully: EDDI_12mn_20111223.asc
# File downloaded successfully: EDDI_12mn_20111217.asc
# File downloaded successfully: EDDI_12mn_20111225.asc
# File downloaded successfully: EDDI_12mn_20111224.asc
# File downloaded successfully: EDDI_12mn_20111226.asc
# File downloaded successfully: EDDI_12mn_20111227.asc
# File downloaded successfully: EDDI_12mn_20111228.asc
# File downloaded successfully: EDDI_12mn_20111229.asc
# File downloaded successfully: EDDI_12mn_20111230.asc
# File downloaded successfully: EDDI_12mn_20111231.asc
# File downloaded successfully: EDDI_12mn_20111202.asc
# Data for year 2011 processed and saved as Parquet at /workspace/soil-ml-modeling-pipeline/ml-modeling-pipeline/data/01_raw/eddi/EDDI_12mn_2011.parquet.
# File downloaded successfully: EDDI_12mn_20120105.asc
# File downloaded successfully: EDDI_12mn_20120102.asc
# File downloaded successfully: EDDI_12mn_20120106.asc
# File downloaded successfully: EDDI_12mn_20120108.asc
# File downloaded successfully: EDDI_12mn_20120104.asc
# File downloaded successfully: EDDI_12mn_20120107.asc
# File downloaded successfully: EDDI_12mn_20120103.asc
# File downloaded successfully: EDDI_12mn_20120109.asc
# File downloaded successfully: EDDI_12mn_20120113.asc
# File downloaded successfully: EDDI_12mn_20120114.asc
# File downloaded successfully: EDDI_12mn_20120110.asc
# File downloaded successfully: EDDI_12mn_20120115.asc
# File downloaded successfully: EDDI_12mn_20120112.asc
# File downloaded successfully: EDDI_12mn_20120116.asc
# File downloaded successfully: EDDI_12mn_20120117.asc
# File downloaded successfully: EDDI_12mn_20120120.asc
# File downloaded successfully: EDDI_12mn_20120121.asc
# File downloaded successfully: EDDI_12mn_20120122.asc
# File downloaded successfully: EDDI_12mn_20120124.asc
# File downloaded successfully: EDDI_12mn_20120125.asc
# File downloaded successfully: EDDI_12mn_20120126.asc
# File downloaded successfully: EDDI_12mn_20120119.asc
# File downloaded successfully: EDDI_12mn_20120127.asc
# File downloaded successfully: EDDI_12mn_20120128.asc
# File downloaded successfully: EDDI_12mn_20120130.asc
# File downloaded successfully: EDDI_12mn_20120129.asc
# File downloaded successfully: EDDI_12mn_20120131.asc
# File downloaded successfully: EDDI_12mn_20120201.asc
# File downloaded successfully: EDDI_12mn_20120123.asc
# File downloaded successfully: EDDI_12mn_20120111.asc
# File downloaded successfully: EDDI_12mn_20120202.asc
# File downloaded successfully: EDDI_12mn_20120203.asc
# File downloaded successfully: EDDI_12mn_20120204.asc
# File downloaded successfully: EDDI_12mn_20120205.asc
# File downloaded successfully: EDDI_12mn_20120118.asc
# File downloaded successfully: EDDI_12mn_20120207.asc
# File downloaded successfully: EDDI_12mn_20120209.asc
# File downloaded successfully: EDDI_12mn_20120208.asc
# File downloaded successfully: EDDI_12mn_20120211.asc
# File downloaded successfully: EDDI_12mn_20120210.asc
# File downloaded successfully: EDDI_12mn_20120101.asc
# File downloaded successfully: EDDI_12mn_20120212.asc
# File downloaded successfully: EDDI_12mn_20120206.asc
# File downloaded successfully: EDDI_12mn_20120213.asc
# File downloaded successfully: EDDI_12mn_20120214.asc
# File downloaded successfully: EDDI_12mn_20120216.asc
# File downloaded successfully: EDDI_12mn_20120217.asc
# File downloaded successfully: EDDI_12mn_20120218.asc
# File downloaded successfully: EDDI_12mn_20120220.asc
# File downloaded successfully: EDDI_12mn_20120219.asc
# File downloaded successfully: EDDI_12mn_20120221.asc
# File downloaded successfully: EDDI_12mn_20120222.asc
# File downloaded successfully: EDDI_12mn_20120223.asc
# File downloaded successfully: EDDI_12mn_20120224.asc
# File downloaded successfully: EDDI_12mn_20120226.asc
# File downloaded successfully: EDDI_12mn_20120227.asc
# File downloaded successfully: EDDI_12mn_20120301.asc
# File downloaded successfully: EDDI_12mn_20120225.asc
# File downloaded successfully: EDDI_12mn_20120302.asc
# File downloaded successfully: EDDI_12mn_20120228.asc
# File downloaded successfully: EDDI_12mn_20120303.asc
# File downloaded successfully: EDDI_12mn_20120305.asc
# File downloaded successfully: EDDI_12mn_20120304.asc
# File downloaded successfully: EDDI_12mn_20120215.asc
# File downloaded successfully: EDDI_12mn_20120308.asc
# File downloaded successfully: EDDI_12mn_20120310.asc
# File downloaded successfully: EDDI_12mn_20120309.asc
# File downloaded successfully: EDDI_12mn_20120311.asc
# File downloaded successfully: EDDI_12mn_20120312.asc
# File downloaded successfully: EDDI_12mn_20120313.asc
# File downloaded successfully: EDDI_12mn_20120307.asc
# File downloaded successfully: EDDI_12mn_20120314.asc
# File downloaded successfully: EDDI_12mn_20120315.asc
# File downloaded successfully: EDDI_12mn_20120316.asc
# File downloaded successfully: EDDI_12mn_20120317.asc
# File downloaded successfully: EDDI_12mn_20120319.asc
# File downloaded successfully: EDDI_12mn_20120320.asc
# File downloaded successfully: EDDI_12mn_20120321.asc
# File downloaded successfully: EDDI_12mn_20120322.asc
# File downloaded successfully: EDDI_12mn_20120324.asc
# File downloaded successfully: EDDI_12mn_20120325.asc
# File downloaded successfully: EDDI_12mn_20120323.asc
# File downloaded successfully: EDDI_12mn_20120306.asc
# File downloaded successfully: EDDI_12mn_20120318.asc
# File downloaded successfully: EDDI_12mn_20120328.asc
# File downloaded successfully: EDDI_12mn_20120330.asc
# File downloaded successfully: EDDI_12mn_20120329.asc
# File downloaded successfully: EDDI_12mn_20120331.asc
# File downloaded successfully: EDDI_12mn_20120401.asc
# File downloaded successfully: EDDI_12mn_20120327.asc
# File downloaded successfully: EDDI_12mn_20120402.asc
# File downloaded successfully: EDDI_12mn_20120403.asc
# File downloaded successfully: EDDI_12mn_20120404.asc
# File downloaded successfully: EDDI_12mn_20120405.asc
# File downloaded successfully: EDDI_12mn_20120326.asc
# File downloaded successfully: EDDI_12mn_20120408.asc
# File downloaded successfully: EDDI_12mn_20120406.asc
# File downloaded successfully: EDDI_12mn_20120407.asc
# File downloaded successfully: EDDI_12mn_20120409.asc
# File downloaded successfully: EDDI_12mn_20120410.asc
# File downloaded successfully: EDDI_12mn_20120411.asc
# File downloaded successfully: EDDI_12mn_20120413.asc
# File downloaded successfully: EDDI_12mn_20120412.asc
# File downloaded successfully: EDDI_12mn_20120414.asc
# File downloaded successfully: EDDI_12mn_20120415.asc
# File downloaded successfully: EDDI_12mn_20120417.asc
# File downloaded successfully: EDDI_12mn_20120416.asc
# File downloaded successfully: EDDI_12mn_20120418.asc
# File downloaded successfully: EDDI_12mn_20120420.asc
# File downloaded successfully: EDDI_12mn_20120419.asc
# File downloaded successfully: EDDI_12mn_20120422.asc
# File downloaded successfully: EDDI_12mn_20120423.asc
# File downloaded successfully: EDDI_12mn_20120421.asc
# File downloaded successfully: EDDI_12mn_20120424.asc
# File downloaded successfully: EDDI_12mn_20120425.asc
# File downloaded successfully: EDDI_12mn_20120427.asc
# File downloaded successfully: EDDI_12mn_20120429.asc
# File downloaded successfully: EDDI_12mn_20120430.asc
# File downloaded successfully: EDDI_12mn_20120428.asc
# File downloaded successfully: EDDI_12mn_20120502.asc
# File downloaded successfully: EDDI_12mn_20120503.asc
# File downloaded successfully: EDDI_12mn_20120501.asc
# File downloaded successfully: EDDI_12mn_20120504.asc
# File downloaded successfully: EDDI_12mn_20120507.asc
# File downloaded successfully: EDDI_12mn_20120505.asc
# File downloaded successfully: EDDI_12mn_20120506.asc
# File downloaded successfully: EDDI_12mn_20120509.asc
# File downloaded successfully: EDDI_12mn_20120426.asc
# File downloaded successfully: EDDI_12mn_20120511.asc
# File downloaded successfully: EDDI_12mn_20120510.asc
# File downloaded successfully: EDDI_12mn_20120512.asc
# File downloaded successfully: EDDI_12mn_20120513.asc
# File downloaded successfully: EDDI_12mn_20120514.asc
# File downloaded successfully: EDDI_12mn_20120515.asc
# File downloaded successfully: EDDI_12mn_20120518.asc
# File downloaded successfully: EDDI_12mn_20120517.asc
# File downloaded successfully: EDDI_12mn_20120519.asc
# File downloaded successfully: EDDI_12mn_20120521.asc
# File downloaded successfully: EDDI_12mn_20120520.asc
# File downloaded successfully: EDDI_12mn_20120522.asc
# File downloaded successfully: EDDI_12mn_20120524.asc
# File downloaded successfully: EDDI_12mn_20120523.asc
# File downloaded successfully: EDDI_12mn_20120525.asc
# File downloaded successfully: EDDI_12mn_20120526.asc
# File downloaded successfully: EDDI_12mn_20120527.asc
# File downloaded successfully: EDDI_12mn_20120516.asc
# File downloaded successfully: EDDI_12mn_20120528.asc
# File downloaded successfully: EDDI_12mn_20120530.asc
# File downloaded successfully: EDDI_12mn_20120529.asc
# File downloaded successfully: EDDI_12mn_20120531.asc
# File downloaded successfully: EDDI_12mn_20120601.asc
# File downloaded successfully: EDDI_12mn_20120603.asc
# File downloaded successfully: EDDI_12mn_20120606.asc
# File downloaded successfully: EDDI_12mn_20120607.asc
# File downloaded successfully: EDDI_12mn_20120602.asc
# File downloaded successfully: EDDI_12mn_20120608.asc
# File downloaded successfully: EDDI_12mn_20120609.asc
# File downloaded successfully: EDDI_12mn_20120610.asc
# File downloaded successfully: EDDI_12mn_20120611.asc
# File downloaded successfully: EDDI_12mn_20120612.asc
# File downloaded successfully: EDDI_12mn_20120613.asc
# File downloaded successfully: EDDI_12mn_20120614.asc
# File downloaded successfully: EDDI_12mn_20120604.asc
# File downloaded successfully: EDDI_12mn_20120508.asc
# File downloaded successfully: EDDI_12mn_20120615.asc
# File downloaded successfully: EDDI_12mn_20120617.asc
# File downloaded successfully: EDDI_12mn_20120618.asc
# File downloaded successfully: EDDI_12mn_20120619.asc
# File downloaded successfully: EDDI_12mn_20120621.asc
# File downloaded successfully: EDDI_12mn_20120622.asc
# File downloaded successfully: EDDI_12mn_20120623.asc
# File downloaded successfully: EDDI_12mn_20120624.asc
# File downloaded successfully: EDDI_12mn_20120620.asc
# File downloaded successfully: EDDI_12mn_20120625.asc
# File downloaded successfully: EDDI_12mn_20120626.asc
# File downloaded successfully: EDDI_12mn_20120616.asc
# File downloaded successfully: EDDI_12mn_20120627.asc
# File downloaded successfully: EDDI_12mn_20120628.asc
# File downloaded successfully: EDDI_12mn_20120629.asc
# File downloaded successfully: EDDI_12mn_20120630.asc
# File downloaded successfully: EDDI_12mn_20120702.asc
# File downloaded successfully: EDDI_12mn_20120701.asc
# File downloaded successfully: EDDI_12mn_20120704.asc
# File downloaded successfully: EDDI_12mn_20120703.asc
# File downloaded successfully: EDDI_12mn_20120705.asc
# File downloaded successfully: EDDI_12mn_20120706.asc
# File downloaded successfully: EDDI_12mn_20120707.asc
# File downloaded successfully: EDDI_12mn_20120708.asc
# File downloaded successfully: EDDI_12mn_20120709.asc
# File downloaded successfully: EDDI_12mn_20120711.asc
# File downloaded successfully: EDDI_12mn_20120605.asc
# File downloaded successfully: EDDI_12mn_20120712.asc
# File downloaded successfully: EDDI_12mn_20120710.asc
# File downloaded successfully: EDDI_12mn_20120713.asc
# File downloaded successfully: EDDI_12mn_20120714.asc
# File downloaded successfully: EDDI_12mn_20120715.asc
# File downloaded successfully: EDDI_12mn_20120716.asc
# File downloaded successfully: EDDI_12mn_20120718.asc
# File downloaded successfully: EDDI_12mn_20120717.asc
# File downloaded successfully: EDDI_12mn_20120719.asc
# File downloaded successfully: EDDI_12mn_20120720.asc
# File downloaded successfully: EDDI_12mn_20120722.asc
# File downloaded successfully: EDDI_12mn_20120721.asc
# File downloaded successfully: EDDI_12mn_20120723.asc
# File downloaded successfully: EDDI_12mn_20120724.asc
# File downloaded successfully: EDDI_12mn_20120725.asc
# File downloaded successfully: EDDI_12mn_20120726.asc
# File downloaded successfully: EDDI_12mn_20120727.asc
# File downloaded successfully: EDDI_12mn_20120728.asc
# File downloaded successfully: EDDI_12mn_20120729.asc
# File downloaded successfully: EDDI_12mn_20120731.asc
# File downloaded successfully: EDDI_12mn_20120801.asc
# File downloaded successfully: EDDI_12mn_20120803.asc
# File downloaded successfully: EDDI_12mn_20120804.asc
# File downloaded successfully: EDDI_12mn_20120802.asc
# File downloaded successfully: EDDI_12mn_20120806.asc
# File downloaded successfully: EDDI_12mn_20120807.asc
# File downloaded successfully: EDDI_12mn_20120808.asc
# File downloaded successfully: EDDI_12mn_20120730.asc
# File downloaded successfully: EDDI_12mn_20120811.asc
# File downloaded successfully: EDDI_12mn_20120813.asc
# File downloaded successfully: EDDI_12mn_20120805.asc
# File downloaded successfully: EDDI_12mn_20120810.asc
# File downloaded successfully: EDDI_12mn_20120814.asc
# File downloaded successfully: EDDI_12mn_20120815.asc
# File downloaded successfully: EDDI_12mn_20120816.asc
# File downloaded successfully: EDDI_12mn_20120817.asc
# File downloaded successfully: EDDI_12mn_20120819.asc
# File downloaded successfully: EDDI_12mn_20120812.asc
# File downloaded successfully: EDDI_12mn_20120818.asc
# File downloaded successfully: EDDI_12mn_20120820.asc
# File downloaded successfully: EDDI_12mn_20120821.asc
# File downloaded successfully: EDDI_12mn_20120822.asc
# File downloaded successfully: EDDI_12mn_20120823.asc
# File downloaded successfully: EDDI_12mn_20120824.asc
# File downloaded successfully: EDDI_12mn_20120825.asc
# File downloaded successfully: EDDI_12mn_20120827.asc
# File downloaded successfully: EDDI_12mn_20120826.asc
# File downloaded successfully: EDDI_12mn_20120828.asc
# File downloaded successfully: EDDI_12mn_20120829.asc
# File downloaded successfully: EDDI_12mn_20120830.asc
# File downloaded successfully: EDDI_12mn_20120809.asc
# File downloaded successfully: EDDI_12mn_20120831.asc
# File downloaded successfully: EDDI_12mn_20120901.asc
# File downloaded successfully: EDDI_12mn_20120902.asc
# File downloaded successfully: EDDI_12mn_20120903.asc
# File downloaded successfully: EDDI_12mn_20120904.asc
# File downloaded successfully: EDDI_12mn_20120905.asc
# File downloaded successfully: EDDI_12mn_20120906.asc
# File downloaded successfully: EDDI_12mn_20120907.asc
# File downloaded successfully: EDDI_12mn_20120908.asc
# File downloaded successfully: EDDI_12mn_20120909.asc
# File downloaded successfully: EDDI_12mn_20120910.asc
# File downloaded successfully: EDDI_12mn_20120911.asc
# File downloaded successfully: EDDI_12mn_20120912.asc
# File downloaded successfully: EDDI_12mn_20120913.asc
# File downloaded successfully: EDDI_12mn_20120914.asc
# File downloaded successfully: EDDI_12mn_20120917.asc
# File downloaded successfully: EDDI_12mn_20120916.asc
# File downloaded successfully: EDDI_12mn_20120918.asc
# File downloaded successfully: EDDI_12mn_20120919.asc
# File downloaded successfully: EDDI_12mn_20120915.asc
# File downloaded successfully: EDDI_12mn_20120920.asc
# File downloaded successfully: EDDI_12mn_20120921.asc
# File downloaded successfully: EDDI_12mn_20120923.asc
# File downloaded successfully: EDDI_12mn_20120924.asc
# File downloaded successfully: EDDI_12mn_20120925.asc
# File downloaded successfully: EDDI_12mn_20120926.asc
# File downloaded successfully: EDDI_12mn_20120927.asc
# File downloaded successfully: EDDI_12mn_20120928.asc
# File downloaded successfully: EDDI_12mn_20120922.asc
# File downloaded successfully: EDDI_12mn_20120930.asc
# File downloaded successfully: EDDI_12mn_20121001.asc
# File downloaded successfully: EDDI_12mn_20120929.asc
# File downloaded successfully: EDDI_12mn_20121002.asc
# File downloaded successfully: EDDI_12mn_20121003.asc
# File downloaded successfully: EDDI_12mn_20121004.asc
# File downloaded successfully: EDDI_12mn_20121005.asc
# File downloaded successfully: EDDI_12mn_20121006.asc
# File downloaded successfully: EDDI_12mn_20121007.asc
# File downloaded successfully: EDDI_12mn_20121009.asc
# File downloaded successfully: EDDI_12mn_20121010.asc
# File downloaded successfully: EDDI_12mn_20121008.asc
# File downloaded successfully: EDDI_12mn_20121013.asc
# File downloaded successfully: EDDI_12mn_20121012.asc
# File downloaded successfully: EDDI_12mn_20121011.asc
# File downloaded successfully: EDDI_12mn_20121014.asc
# File downloaded successfully: EDDI_12mn_20121015.asc
# File downloaded successfully: EDDI_12mn_20121016.asc
# File downloaded successfully: EDDI_12mn_20121018.asc
# File downloaded successfully: EDDI_12mn_20121017.asc
# File downloaded successfully: EDDI_12mn_20121020.asc
# File downloaded successfully: EDDI_12mn_20121021.asc
# File downloaded successfully: EDDI_12mn_20121022.asc
# File downloaded successfully: EDDI_12mn_20121023.asc
# File downloaded successfully: EDDI_12mn_20121024.asc
# File downloaded successfully: EDDI_12mn_20121025.asc
# File downloaded successfully: EDDI_12mn_20121019.asc
# File downloaded successfully: EDDI_12mn_20121026.asc
# File downloaded successfully: EDDI_12mn_20121027.asc
# File downloaded successfully: EDDI_12mn_20121028.asc
# File downloaded successfully: EDDI_12mn_20121029.asc
# File downloaded successfully: EDDI_12mn_20121030.asc
# File downloaded successfully: EDDI_12mn_20121102.asc
# File downloaded successfully: EDDI_12mn_20121101.asc
# File downloaded successfully: EDDI_12mn_20121103.asc
# File downloaded successfully: EDDI_12mn_20121104.asc
# File downloaded successfully: EDDI_12mn_20121105.asc
# File downloaded successfully: EDDI_12mn_20121106.asc
# File downloaded successfully: EDDI_12mn_20121031.asc
# File downloaded successfully: EDDI_12mn_20121107.asc
# File downloaded successfully: EDDI_12mn_20121108.asc
# File downloaded successfully: EDDI_12mn_20121109.asc
# File downloaded successfully: EDDI_12mn_20121110.asc
# File downloaded successfully: EDDI_12mn_20121112.asc
# File downloaded successfully: EDDI_12mn_20121111.asc
# File downloaded successfully: EDDI_12mn_20121113.asc
# File downloaded successfully: EDDI_12mn_20121114.asc
# File downloaded successfully: EDDI_12mn_20121115.asc
# File downloaded successfully: EDDI_12mn_20121118.asc
# File downloaded successfully: EDDI_12mn_20121119.asc
# File downloaded successfully: EDDI_12mn_20121120.asc
# File downloaded successfully: EDDI_12mn_20121116.asc
# File downloaded successfully: EDDI_12mn_20121117.asc
# File downloaded successfully: EDDI_12mn_20121122.asc
# File downloaded successfully: EDDI_12mn_20121123.asc
# File downloaded successfully: EDDI_12mn_20121121.asc
# File downloaded successfully: EDDI_12mn_20121125.asc
# File downloaded successfully: EDDI_12mn_20121124.asc
# File downloaded successfully: EDDI_12mn_20121126.asc
# File downloaded successfully: EDDI_12mn_20121127.asc
# File downloaded successfully: EDDI_12mn_20121128.asc
# File downloaded successfully: EDDI_12mn_20121129.asc
# File downloaded successfully: EDDI_12mn_20121130.asc
# File downloaded successfully: EDDI_12mn_20121201.asc
# File downloaded successfully: EDDI_12mn_20121203.asc
# File downloaded successfully: EDDI_12mn_20121204.asc
# File downloaded successfully: EDDI_12mn_20121205.asc
# File downloaded successfully: EDDI_12mn_20121206.asc
# File downloaded successfully: EDDI_12mn_20121208.asc
# File downloaded successfully: EDDI_12mn_20121207.asc
# File downloaded successfully: EDDI_12mn_20121202.asc
# File downloaded successfully: EDDI_12mn_20121209.asc
# File downloaded successfully: EDDI_12mn_20121210.asc
# File downloaded successfully: EDDI_12mn_20121211.asc
# File downloaded successfully: EDDI_12mn_20121216.asc
# File downloaded successfully: EDDI_12mn_20121215.asc
# File downloaded successfully: EDDI_12mn_20121214.asc
# File downloaded successfully: EDDI_12mn_20121212.asc
# File downloaded successfully: EDDI_12mn_20121213.asc
# File downloaded successfully: EDDI_12mn_20121217.asc
# File downloaded successfully: EDDI_12mn_20121219.asc
# File downloaded successfully: EDDI_12mn_20121218.asc
# File downloaded successfully: EDDI_12mn_20121221.asc
# File downloaded successfully: EDDI_12mn_20121222.asc
# File downloaded successfully: EDDI_12mn_20121223.asc
# File downloaded successfully: EDDI_12mn_20121224.asc
# File downloaded successfully: EDDI_12mn_20121220.asc
# File downloaded successfully: EDDI_12mn_20121225.asc
# File downloaded successfully: EDDI_12mn_20121227.asc
# File downloaded successfully: EDDI_12mn_20121229.asc
# File downloaded successfully: EDDI_12mn_20121226.asc
# File downloaded successfully: EDDI_12mn_20121230.asc
# File downloaded successfully: EDDI_12mn_20121231.asc
# File downloaded successfully: EDDI_12mn_20121228.asc
# Data for year 2012 processed and saved as Parquet at /workspace/soil-ml-modeling-pipeline/ml-modeling-pipeline/data/01_raw/eddi/EDDI_12mn_2012.parquet.
# File downloaded successfully: EDDI_12mn_20130108.asc
# File downloaded successfully: EDDI_12mn_20130106.asc
# File downloaded successfully: EDDI_12mn_20130101.asc
# File downloaded successfully: EDDI_12mn_20130103.asc
# File downloaded successfully: EDDI_12mn_20130102.asc
# File downloaded successfully: EDDI_12mn_20130105.asc
# File downloaded successfully: EDDI_12mn_20130104.asc
# File downloaded successfully: EDDI_12mn_20130107.asc
# File downloaded successfully: EDDI_12mn_20130109.asc
# File downloaded successfully: EDDI_12mn_20130110.asc
# File downloaded successfully: EDDI_12mn_20130111.asc
# File downloaded successfully: EDDI_12mn_20130112.asc
# File downloaded successfully: EDDI_12mn_20130114.asc
# File downloaded successfully: EDDI_12mn_20130113.asc
# File downloaded successfully: EDDI_12mn_20130115.asc
# File downloaded successfully: EDDI_12mn_20130116.asc
# File downloaded successfully: EDDI_12mn_20130117.asc
# File downloaded successfully: EDDI_12mn_20130119.asc
# File downloaded successfully: EDDI_12mn_20130120.asc
# File downloaded successfully: EDDI_12mn_20130121.asc
# File downloaded successfully: EDDI_12mn_20130123.asc
# File downloaded successfully: EDDI_12mn_20130122.asc
# File downloaded successfully: EDDI_12mn_20130124.asc
# File downloaded successfully: EDDI_12mn_20130125.asc
# File downloaded successfully: EDDI_12mn_20130127.asc
# File downloaded successfully: EDDI_12mn_20130128.asc
# File downloaded successfully: EDDI_12mn_20130129.asc
# File downloaded successfully: EDDI_12mn_20130118.asc
# File downloaded successfully: EDDI_12mn_20130126.asc
# File downloaded successfully: EDDI_12mn_20130130.asc
# File downloaded successfully: EDDI_12mn_20130131.asc
# File downloaded successfully: EDDI_12mn_20130202.asc
# File downloaded successfully: EDDI_12mn_20130201.asc
# File downloaded successfully: EDDI_12mn_20130206.asc
# File downloaded successfully: EDDI_12mn_20130203.asc
# File downloaded successfully: EDDI_12mn_20130207.asc
# File downloaded successfully: EDDI_12mn_20130204.asc
# File downloaded successfully: EDDI_12mn_20130208.asc
# File downloaded successfully: EDDI_12mn_20130205.asc
# File downloaded successfully: EDDI_12mn_20130209.asc
# File downloaded successfully: EDDI_12mn_20130211.asc
# File downloaded successfully: EDDI_12mn_20130210.asc
# File downloaded successfully: EDDI_12mn_20130214.asc
# File downloaded successfully: EDDI_12mn_20130212.asc
# File downloaded successfully: EDDI_12mn_20130213.asc
# File downloaded successfully: EDDI_12mn_20130215.asc
# File downloaded successfully: EDDI_12mn_20130216.asc
# File downloaded successfully: EDDI_12mn_20130218.asc
# File downloaded successfully: EDDI_12mn_20130219.asc
# File downloaded successfully: EDDI_12mn_20130220.asc
# File downloaded successfully: EDDI_12mn_20130221.asc
# File downloaded successfully: EDDI_12mn_20130222.asc
# File downloaded successfully: EDDI_12mn_20130223.asc
# File downloaded successfully: EDDI_12mn_20130217.asc
# File downloaded successfully: EDDI_12mn_20130224.asc
# File downloaded successfully: EDDI_12mn_20130225.asc
# File downloaded successfully: EDDI_12mn_20130226.asc
# File downloaded successfully: EDDI_12mn_20130227.asc
# File downloaded successfully: EDDI_12mn_20130302.asc
# File downloaded successfully: EDDI_12mn_20130301.asc
# File downloaded successfully: EDDI_12mn_20130228.asc
# File downloaded successfully: EDDI_12mn_20130304.asc
# File downloaded successfully: EDDI_12mn_20130305.asc
# File downloaded successfully: EDDI_12mn_20130306.asc
# File downloaded successfully: EDDI_12mn_20130303.asc
# File downloaded successfully: EDDI_12mn_20130307.asc
# File downloaded successfully: EDDI_12mn_20130308.asc
# File downloaded successfully: EDDI_12mn_20130309.asc
# File downloaded successfully: EDDI_12mn_20130310.asc
# File downloaded successfully: EDDI_12mn_20130312.asc
# File downloaded successfully: EDDI_12mn_20130313.asc
# File downloaded successfully: EDDI_12mn_20130311.asc
# File downloaded successfully: EDDI_12mn_20130316.asc
# File downloaded successfully: EDDI_12mn_20130314.asc
# File downloaded successfully: EDDI_12mn_20130315.asc
# File downloaded successfully: EDDI_12mn_20130318.asc
# File downloaded successfully: EDDI_12mn_20130321.asc
# File downloaded successfully: EDDI_12mn_20130320.asc
# File downloaded successfully: EDDI_12mn_20130319.asc
# File downloaded successfully: EDDI_12mn_20130322.asc
# File downloaded successfully: EDDI_12mn_20130323.asc
# File downloaded successfully: EDDI_12mn_20130317.asc
# File downloaded successfully: EDDI_12mn_20130325.asc
# File downloaded successfully: EDDI_12mn_20130327.asc
# File downloaded successfully: EDDI_12mn_20130329.asc
# File downloaded successfully: EDDI_12mn_20130331.asc
# File downloaded successfully: EDDI_12mn_20130330.asc
# File downloaded successfully: EDDI_12mn_20130326.asc
# File downloaded successfully: EDDI_12mn_20130328.asc
# File downloaded successfully: EDDI_12mn_20130401.asc
# File downloaded successfully: EDDI_12mn_20130403.asc
# File downloaded successfully: EDDI_12mn_20130402.asc
# File downloaded successfully: EDDI_12mn_20130405.asc
# File downloaded successfully: EDDI_12mn_20130406.asc
# File downloaded successfully: EDDI_12mn_20130407.asc
# File downloaded successfully: EDDI_12mn_20130408.asc
# File downloaded successfully: EDDI_12mn_20130409.asc
# File downloaded successfully: EDDI_12mn_20130410.asc
# File downloaded successfully: EDDI_12mn_20130404.asc
# File downloaded successfully: EDDI_12mn_20130411.asc
# File downloaded successfully: EDDI_12mn_20130412.asc
# File downloaded successfully: EDDI_12mn_20130413.asc
# File downloaded successfully: EDDI_12mn_20130414.asc
# File downloaded successfully: EDDI_12mn_20130415.asc
# File downloaded successfully: EDDI_12mn_20130416.asc
# File downloaded successfully: EDDI_12mn_20130417.asc
# File downloaded successfully: EDDI_12mn_20130418.asc
# File downloaded successfully: EDDI_12mn_20130324.asc
# File downloaded successfully: EDDI_12mn_20130420.asc
# File downloaded successfully: EDDI_12mn_20130419.asc
# File downloaded successfully: EDDI_12mn_20130422.asc
# File downloaded successfully: EDDI_12mn_20130423.asc
# File downloaded successfully: EDDI_12mn_20130424.asc
# File downloaded successfully: EDDI_12mn_20130426.asc
# File downloaded successfully: EDDI_12mn_20130427.asc
# File downloaded successfully: EDDI_12mn_20130429.asc
# File downloaded successfully: EDDI_12mn_20130425.asc
# File downloaded successfully: EDDI_12mn_20130430.asc
# File downloaded successfully: EDDI_12mn_20130421.asc
# File downloaded successfully: EDDI_12mn_20130428.asc
# File downloaded successfully: EDDI_12mn_20130501.asc
# File downloaded successfully: EDDI_12mn_20130502.asc
# File downloaded successfully: EDDI_12mn_20130503.asc
# File downloaded successfully: EDDI_12mn_20130504.asc
# File downloaded successfully: EDDI_12mn_20130505.asc
# File downloaded successfully: EDDI_12mn_20130506.asc
# File downloaded successfully: EDDI_12mn_20130507.asc
# File downloaded successfully: EDDI_12mn_20130509.asc
# File downloaded successfully: EDDI_12mn_20130508.asc
# File downloaded successfully: EDDI_12mn_20130510.asc
# File downloaded successfully: EDDI_12mn_20130511.asc
# File downloaded successfully: EDDI_12mn_20130512.asc
# File downloaded successfully: EDDI_12mn_20130513.asc
# File downloaded successfully: EDDI_12mn_20130514.asc
# File downloaded successfully: EDDI_12mn_20130515.asc
# File downloaded successfully: EDDI_12mn_20130516.asc
# File downloaded successfully: EDDI_12mn_20130517.asc
# File downloaded successfully: EDDI_12mn_20130518.asc
# File downloaded successfully: EDDI_12mn_20130519.asc
# File downloaded successfully: EDDI_12mn_20130521.asc
# File downloaded successfully: EDDI_12mn_20130520.asc
# File downloaded successfully: EDDI_12mn_20130522.asc
# File downloaded successfully: EDDI_12mn_20130523.asc
# File downloaded successfully: EDDI_12mn_20130524.asc
# File downloaded successfully: EDDI_12mn_20130525.asc
# File downloaded successfully: EDDI_12mn_20130526.asc
# File downloaded successfully: EDDI_12mn_20130527.asc
# File downloaded successfully: EDDI_12mn_20130528.asc
# File downloaded successfully: EDDI_12mn_20130529.asc
# File downloaded successfully: EDDI_12mn_20130530.asc
# File downloaded successfully: EDDI_12mn_20130531.asc
# File downloaded successfully: EDDI_12mn_20130602.asc
# File downloaded successfully: EDDI_12mn_20130601.asc
# File downloaded successfully: EDDI_12mn_20130603.asc
# File downloaded successfully: EDDI_12mn_20130604.asc
# File downloaded successfully: EDDI_12mn_20130607.asc
# File downloaded successfully: EDDI_12mn_20130608.asc
# File downloaded successfully: EDDI_12mn_20130609.asc
# File downloaded successfully: EDDI_12mn_20130610.asc
# File downloaded successfully: EDDI_12mn_20130612.asc
# File downloaded successfully: EDDI_12mn_20130611.asc
# File downloaded successfully: EDDI_12mn_20130613.asc
# File downloaded successfully: EDDI_12mn_20130614.asc
# File downloaded successfully: EDDI_12mn_20130616.asc
# File downloaded successfully: EDDI_12mn_20130615.asc
# File downloaded successfully: EDDI_12mn_20130617.asc
# File downloaded successfully: EDDI_12mn_20130618.asc
# File downloaded successfully: EDDI_12mn_20130619.asc
# File downloaded successfully: EDDI_12mn_20130620.asc
# ...
# File downloaded successfully: EDDI_12mn_20230708.asc
# File downloaded successfully: EDDI_12mn_20230710.asc
# File downloaded successfully: EDDI_12mn_20230712.asc
# File downloaded successfully: EDDI_12mn_20230711.asc
# File downloaded successfully: EDDI_12mn_20230713.asc
# File downloaded successfully: EDDI_12mn_20230715.asc
# File downloaded successfully: EDDI_12mn_20230714.asc
# File downloaded successfully: EDDI_12mn_20230716.asc
# File downloaded successfully: EDDI_12mn_20230717.asc
# File downloaded successfully: EDDI_12mn_20230718.asc
# File downloaded successfully: EDDI_12mn_20230720.asc
# File downloaded successfully: EDDI_12mn_20230719.asc
# File downloaded successfully: EDDI_12mn_20230721.asc
# File downloaded successfully: EDDI_12mn_20230722.asc
# File downloaded successfully: EDDI_12mn_20230723.asc
# File downloaded successfully: EDDI_12mn_20230724.asc
# File downloaded successfully: EDDI_12mn_20230725.asc
# File downloaded successfully: EDDI_12mn_20230726.asc
# File downloaded successfully: EDDI_12mn_20230727.asc
# File downloaded successfully: EDDI_12mn_20230729.asc
# File downloaded successfully: EDDI_12mn_20230728.asc
# File downloaded successfully: EDDI_12mn_20230730.asc
# File downloaded successfully: EDDI_12mn_20230731.asc
# File downloaded successfully: EDDI_12mn_20230801.asc
# File downloaded successfully: EDDI_12mn_20230802.asc
# File downloaded successfully: EDDI_12mn_20230803.asc
# File downloaded successfully: EDDI_12mn_20230806.asc
# File downloaded successfully: EDDI_12mn_20230805.asc
# File downloaded successfully: EDDI_12mn_20230808.asc
# File downloaded successfully: EDDI_12mn_20230809.asc
# File downloaded successfully: EDDI_12mn_20230807.asc
# File downloaded successfully: EDDI_12mn_20230810.asc
# File downloaded successfully: EDDI_12mn_20230811.asc
# File downloaded successfully: EDDI_12mn_20230812.asc
# File downloaded successfully: EDDI_12mn_20230813.asc
# File downloaded successfully: EDDI_12mn_20230814.asc
# File downloaded successfully: EDDI_12mn_20230815.asc
# File downloaded successfully: EDDI_12mn_20230816.asc
# File downloaded successfully: EDDI_12mn_20230817.asc
# File downloaded successfully: EDDI_12mn_20230818.asc
# File downloaded successfully: EDDI_12mn_20230804.asc
# File downloaded successfully: EDDI_12mn_20230819.asc
# File downloaded successfully: EDDI_12mn_20230820.asc
# File downloaded successfully: EDDI_12mn_20230821.asc
# File downloaded successfully: EDDI_12mn_20230823.asc
# File downloaded successfully: EDDI_12mn_20230822.asc
# File downloaded successfully: EDDI_12mn_20230824.asc
# File downloaded successfully: EDDI_12mn_20230825.asc
# File downloaded successfully: EDDI_12mn_20230826.asc
# File downloaded successfully: EDDI_12mn_20230827.asc
# File downloaded successfully: EDDI_12mn_20230828.asc
# File downloaded successfully: EDDI_12mn_20230829.asc
# File downloaded successfully: EDDI_12mn_20230830.asc
# File downloaded successfully: EDDI_12mn_20230831.asc
# File downloaded successfully: EDDI_12mn_20230902.asc
# File downloaded successfully: EDDI_12mn_20230901.asc
# File downloaded successfully: EDDI_12mn_20230903.asc
# File downloaded successfully: EDDI_12mn_20230904.asc
# File downloaded successfully: EDDI_12mn_20230905.asc
# File downloaded successfully: EDDI_12mn_20230907.asc
# File downloaded successfully: EDDI_12mn_20230906.asc
# File downloaded successfully: EDDI_12mn_20230908.asc
# File downloaded successfully: EDDI_12mn_20230909.asc
# File downloaded successfully: EDDI_12mn_20230910.asc
# File downloaded successfully: EDDI_12mn_20230911.asc
# File downloaded successfully: EDDI_12mn_20230912.asc
# File downloaded successfully: EDDI_12mn_20230913.asc
# File downloaded successfully: EDDI_12mn_20230915.asc
# File downloaded successfully: EDDI_12mn_20230916.asc
# File downloaded successfully: EDDI_12mn_20230917.asc
# File downloaded successfully: EDDI_12mn_20230918.asc
# File downloaded successfully: EDDI_12mn_20230919.asc
# File downloaded successfully: EDDI_12mn_20230914.asc
# File downloaded successfully: EDDI_12mn_20230920.asc
# File downloaded successfully: EDDI_12mn_20230921.asc
# File downloaded successfully: EDDI_12mn_20230923.asc
# File downloaded successfully: EDDI_12mn_20230925.asc
# File downloaded successfully: EDDI_12mn_20230924.asc
# File downloaded successfully: EDDI_12mn_20230922.asc
# File downloaded successfully: EDDI_12mn_20230926.asc
# File downloaded successfully: EDDI_12mn_20230927.asc
# File downloaded successfully: EDDI_12mn_20230928.asc
# File downloaded successfully: EDDI_12mn_20230929.asc
# File downloaded successfully: EDDI_12mn_20230930.asc
# File downloaded successfully: EDDI_12mn_20231001.asc
# File downloaded successfully: EDDI_12mn_20231002.asc
# File downloaded successfully: EDDI_12mn_20231003.asc
# File downloaded successfully: EDDI_12mn_20231004.asc
# File downloaded successfully: EDDI_12mn_20231005.asc
# File downloaded successfully: EDDI_12mn_20231006.asc
# File downloaded successfully: EDDI_12mn_20231007.asc
# File downloaded successfully: EDDI_12mn_20231008.asc
# File downloaded successfully: EDDI_12mn_20231009.asc
# File downloaded successfully: EDDI_12mn_20231010.asc
# File downloaded successfully: EDDI_12mn_20231011.asc
# File downloaded successfully: EDDI_12mn_20231012.asc
# File downloaded successfully: EDDI_12mn_20231013.asc
# File downloaded successfully: EDDI_12mn_20231014.asc
# File downloaded successfully: EDDI_12mn_20231015.asc
# File downloaded successfully: EDDI_12mn_20231016.asc
# File downloaded successfully: EDDI_12mn_20231017.asc
# File downloaded successfully: EDDI_12mn_20231018.asc
# File downloaded successfully: EDDI_12mn_20231019.asc
# File downloaded successfully: EDDI_12mn_20231020.asc
# File downloaded successfully: EDDI_12mn_20231021.asc
# File downloaded successfully: EDDI_12mn_20231023.asc
# File downloaded successfully: EDDI_12mn_20231022.asc
# File downloaded successfully: EDDI_12mn_20231024.asc
# File downloaded successfully: EDDI_12mn_20231025.asc
# File downloaded successfully: EDDI_12mn_20231026.asc
# File downloaded successfully: EDDI_12mn_20231027.asc
# File downloaded successfully: EDDI_12mn_20231028.asc
# File downloaded successfully: EDDI_12mn_20231029.asc
# File downloaded successfully: EDDI_12mn_20231030.asc
# File downloaded successfully: EDDI_12mn_20231031.asc
# File downloaded successfully: EDDI_12mn_20231101.asc
# File downloaded successfully: EDDI_12mn_20231102.asc
# File downloaded successfully: EDDI_12mn_20231103.asc
# File downloaded successfully: EDDI_12mn_20231104.asc
# File downloaded successfully: EDDI_12mn_20231105.asc
# File downloaded successfully: EDDI_12mn_20231107.asc
# File downloaded successfully: EDDI_12mn_20231106.asc
# File downloaded successfully: EDDI_12mn_20231108.asc
# File downloaded successfully: EDDI_12mn_20231109.asc
# File downloaded successfully: EDDI_12mn_20231110.asc
# File downloaded successfully: EDDI_12mn_20231112.asc
# File downloaded successfully: EDDI_12mn_20231111.asc
# File downloaded successfully: EDDI_12mn_20231113.asc
# File downloaded successfully: EDDI_12mn_20231114.asc
# File downloaded successfully: EDDI_12mn_20231115.asc
# File downloaded successfully: EDDI_12mn_20231116.asc
# File downloaded successfully: EDDI_12mn_20231117.asc
# File downloaded successfully: EDDI_12mn_20231118.asc
# File downloaded successfully: EDDI_12mn_20231119.asc
# File downloaded successfully: EDDI_12mn_20231120.asc
# File downloaded successfully: EDDI_12mn_20231121.asc
# File downloaded successfully: EDDI_12mn_20231122.asc
# File downloaded successfully: EDDI_12mn_20231123.asc
# File downloaded successfully: EDDI_12mn_20231124.asc
# File downloaded successfully: EDDI_12mn_20231125.asc
# File downloaded successfully: EDDI_12mn_20231126.asc
# File downloaded successfully: EDDI_12mn_20231127.asc
# File downloaded successfully: EDDI_12mn_20231129.asc
# File downloaded successfully: EDDI_12mn_20231130.asc
# File downloaded successfully: EDDI_12mn_20231128.asc
# File downloaded successfully: EDDI_12mn_20231201.asc
# File downloaded successfully: EDDI_12mn_20231202.asc
# File downloaded successfully: EDDI_12mn_20231203.asc
# File downloaded successfully: EDDI_12mn_20231204.asc
# File downloaded successfully: EDDI_12mn_20231205.asc
# File downloaded successfully: EDDI_12mn_20231207.asc
# File downloaded successfully: EDDI_12mn_20231208.asc
# File downloaded successfully: EDDI_12mn_20231210.asc
# File downloaded successfully: EDDI_12mn_20231209.asc
# File downloaded successfully: EDDI_12mn_20231206.asc
# File downloaded successfully: EDDI_12mn_20231211.asc
# File downloaded successfully: EDDI_12mn_20231212.asc
# File downloaded successfully: EDDI_12mn_20231213.asc
# File downloaded successfully: EDDI_12mn_20231214.asc
# File downloaded successfully: EDDI_12mn_20231215.asc
# File downloaded successfully: EDDI_12mn_20231216.asc
# File downloaded successfully: EDDI_12mn_20231217.asc
# File downloaded successfully: EDDI_12mn_20231219.asc
# File downloaded successfully: EDDI_12mn_20231218.asc
# File downloaded successfully: EDDI_12mn_20231220.asc
# File downloaded successfully: EDDI_12mn_20231221.asc
# File downloaded successfully: EDDI_12mn_20231222.asc
# File downloaded successfully: EDDI_12mn_20231223.asc
# File downloaded successfully: EDDI_12mn_20231224.asc
# File downloaded successfully: EDDI_12mn_20231225.asc
# File downloaded successfully: EDDI_12mn_20231226.asc
# File downloaded successfully: EDDI_12mn_20231227.asc
# File downloaded successfully: EDDI_12mn_20231228.asc
# File downloaded successfully: EDDI_12mn_20231229.asc
# File downloaded successfully: EDDI_12mn_20231231.asc
# File downloaded successfully: EDDI_12mn_20231230.asc
# Data for year 2023 processed and saved as Parquet at /workspace/soil-ml-modeling-pipeline/ml-modeling-pipeline/data/01_raw/eddi/EDDI_12mn_2023.parquet.
# File downloaded successfully: EDDI_12mn_20240102.asc
# File downloaded successfully: EDDI_12mn_20240108.asc
# File downloaded successfully: EDDI_12mn_20240104.asc
# File downloaded successfully: EDDI_12mn_20240101.asc
# File downloaded successfully: EDDI_12mn_20240107.asc
# File downloaded successfully: EDDI_12mn_20240105.asc
# File downloaded successfully: EDDI_12mn_20240109.asc
# File downloaded successfully: EDDI_12mn_20240110.asc
# File downloaded successfully: EDDI_12mn_20240114.asc
# File downloaded successfully: EDDI_12mn_20240112.asc
# File downloaded successfully: EDDI_12mn_20240111.asc
# File downloaded successfully: EDDI_12mn_20240113.asc
# File downloaded successfully: EDDI_12mn_20240103.asc
# File downloaded successfully: EDDI_12mn_20240115.asc
# File downloaded successfully: EDDI_12mn_20240116.asc
# File downloaded successfully: EDDI_12mn_20240119.ascFile downloaded successfully: EDDI_12mn_20240118.asc
#
# File downloaded successfully: EDDI_12mn_20240120.asc
# File downloaded successfully: EDDI_12mn_20240121.asc
# File downloaded successfully: EDDI_12mn_20240117.asc
# File downloaded successfully: EDDI_12mn_20240122.asc
# File downloaded successfully: EDDI_12mn_20240123.asc
# File downloaded successfully: EDDI_12mn_20240124.asc
# File downloaded successfully: EDDI_12mn_20240125.asc
# File downloaded successfully: EDDI_12mn_20240126.asc
# File downloaded successfully: EDDI_12mn_20240127.asc
# File downloaded successfully: EDDI_12mn_20240128.asc
# File downloaded successfully: EDDI_12mn_20240106.asc
# File downloaded successfully: EDDI_12mn_20240129.asc
# File downloaded successfully: EDDI_12mn_20240130.asc
# File downloaded successfully: EDDI_12mn_20240131.asc
# File downloaded successfully: EDDI_12mn_20240201.asc
# File downloaded successfully: EDDI_12mn_20240202.asc
# File downloaded successfully: EDDI_12mn_20240203.asc
# File downloaded successfully: EDDI_12mn_20240204.asc
# File downloaded successfully: EDDI_12mn_20240205.asc
# File downloaded successfully: EDDI_12mn_20240206.asc
# File downloaded successfully: EDDI_12mn_20240207.asc
# File downloaded successfully: EDDI_12mn_20240208.asc
# File downloaded successfully: EDDI_12mn_20240209.asc
# File downloaded successfully: EDDI_12mn_20240210.asc
# File downloaded successfully: EDDI_12mn_20240211.asc
# File downloaded successfully: EDDI_12mn_20240212.asc
# File downloaded successfully: EDDI_12mn_20240213.asc
# File downloaded successfully: EDDI_12mn_20240215.asc
# File downloaded successfully: EDDI_12mn_20240216.asc
# File downloaded successfully: EDDI_12mn_20240217.asc
# File downloaded successfully: EDDI_12mn_20240218.asc
# File downloaded successfully: EDDI_12mn_20240219.asc
# File downloaded successfully: EDDI_12mn_20240220.asc
# File downloaded successfully: EDDI_12mn_20240214.asc
# File downloaded successfully: EDDI_12mn_20240221.asc
# File downloaded successfully: EDDI_12mn_20240222.asc
# File downloaded successfully: EDDI_12mn_20240223.asc
# File downloaded successfully: EDDI_12mn_20240224.asc
# File downloaded successfully: EDDI_12mn_20240225.asc
# File downloaded successfully: EDDI_12mn_20240226.asc
# File downloaded successfully: EDDI_12mn_20240227.asc
# File downloaded successfully: EDDI_12mn_20240229.asc
# File downloaded successfully: EDDI_12mn_20240301.asc
# File downloaded successfully: EDDI_12mn_20240302.asc
# File downloaded successfully: EDDI_12mn_20240303.asc
# File downloaded successfully: EDDI_12mn_20240304.asc
# File downloaded successfully: EDDI_12mn_20240228.asc
# File downloaded successfully: EDDI_12mn_20240305.asc
# File downloaded successfully: EDDI_12mn_20240306.asc
# File downloaded successfully: EDDI_12mn_20240307.asc
# File downloaded successfully: EDDI_12mn_20240308.asc
# File downloaded successfully: EDDI_12mn_20240309.asc
# File downloaded successfully: EDDI_12mn_20240311.asc
# File downloaded successfully: EDDI_12mn_20240312.asc
# File downloaded successfully: EDDI_12mn_20240313.asc
# File downloaded successfully: EDDI_12mn_20240310.asc
# File downloaded successfully: EDDI_12mn_20240314.asc
# File downloaded successfully: EDDI_12mn_20240315.asc
# File downloaded successfully: EDDI_12mn_20240316.asc
# File downloaded successfully: EDDI_12mn_20240317.asc
# File downloaded successfully: EDDI_12mn_20240318.asc
# File downloaded successfully: EDDI_12mn_20240319.asc
# File downloaded successfully: EDDI_12mn_20240320.asc
# File downloaded successfully: EDDI_12mn_20240322.asc
# File downloaded successfully: EDDI_12mn_20240321.asc
# File downloaded successfully: EDDI_12mn_20240323.asc
# File downloaded successfully: EDDI_12mn_20240324.asc
# File downloaded successfully: EDDI_12mn_20240325.asc
# File downloaded successfully: EDDI_12mn_20240326.asc
# File downloaded successfully: EDDI_12mn_20240327.asc
# File downloaded successfully: EDDI_12mn_20240328.asc
# File downloaded successfully: EDDI_12mn_20240329.asc
# File downloaded successfully: EDDI_12mn_20240330.asc
# File downloaded successfully: EDDI_12mn_20240331.asc
# File downloaded successfully: EDDI_12mn_20240401.asc
# File downloaded successfully: EDDI_12mn_20240402.asc
# File downloaded successfully: EDDI_12mn_20240403.asc
# File downloaded successfully: EDDI_12mn_20240404.asc
# File downloaded successfully: EDDI_12mn_20240406.asc
# File downloaded successfully: EDDI_12mn_20240407.asc
# File downloaded successfully: EDDI_12mn_20240405.asc
# File downloaded successfully: EDDI_12mn_20240408.asc
# File downloaded successfully: EDDI_12mn_20240409.asc
# File downloaded successfully: EDDI_12mn_20240410.asc
# File downloaded successfully: EDDI_12mn_20240411.asc
# File downloaded successfully: EDDI_12mn_20240412.asc
# File downloaded successfully: EDDI_12mn_20240413.asc
# File downloaded successfully: EDDI_12mn_20240414.asc
# File downloaded successfully: EDDI_12mn_20240415.asc
# File downloaded successfully: EDDI_12mn_20240416.asc
# File downloaded successfully: EDDI_12mn_20240418.asc
# File downloaded successfully: EDDI_12mn_20240419.asc
# File downloaded successfully: EDDI_12mn_20240417.asc
# File downloaded successfully: EDDI_12mn_20240420.asc
# File downloaded successfully: EDDI_12mn_20240421.asc
# File downloaded successfully: EDDI_12mn_20240423.asc
# File downloaded successfully: EDDI_12mn_20240422.asc
# File downloaded successfully: EDDI_12mn_20240424.asc
# File downloaded successfully: EDDI_12mn_20240425.asc
# File downloaded successfully: EDDI_12mn_20240426.asc
# File downloaded successfully: EDDI_12mn_20240427.asc
# File downloaded successfully: EDDI_12mn_20240428.asc
# File downloaded successfully: EDDI_12mn_20240429.asc
# Data for year 2024 processed and saved as Parquet at /workspace/soil-ml-modeling-pipeline/ml-modeling-pipeline/data/01_raw/eddi/EDDI_12mn_2024.parquet.

# %%
# Define the path to your Parquet file
parquet_file_path = "/workspace/soil-ml-modeling-pipeline/ml-modeling-pipeline/data/01_raw/eddi/EDDI_12mn_1981.parquet"

# Use Polars to read the Parquet file
df = pl.read_parquet(parquet_file_path)

# %%
df
# Out:
# shape: (1_439_560, 4)
# ┌────────────┬───────┬──────┬──────────┐
# │ time       ┆ lat   ┆ lon  ┆ eddi     │
# │ ---        ┆ ---   ┆ ---  ┆ ---      │
# │ str        ┆ f64   ┆ f64  ┆ f32      │
# ╞════════════╪═══════╪══════╪══════════╡
# │ 1981-01-08 ┆ 22.0  ┆ 23.0 ┆ -0.17379 │
# │ 1981-01-08 ┆ 22.0  ┆ 23.5 ┆ -0.17379 │
# │ 1981-01-08 ┆ 22.0  ┆ 24.0 ┆ -0.17379 │
# │ 1981-01-08 ┆ 22.0  ┆ 24.5 ┆ -0.17379 │
# │ 1981-01-08 ┆ 22.0  ┆ 25.0 ┆ -0.17379 │
# │ …          ┆ …     ┆ …    ┆ …        │
# │ 1981-12-31 ┆ -11.5 ┆ 49.5 ┆ -999.0   │
# │ 1981-12-31 ┆ -11.5 ┆ 50.0 ┆ -999.0   │
# │ 1981-12-31 ┆ -11.5 ┆ 50.5 ┆ -999.0   │
# │ 1981-12-31 ┆ -11.5 ┆ 51.0 ┆ -999.0   │
# │ 1981-12-31 ┆ -11.5 ┆ 51.5 ┆ -999.0   │
# └────────────┴───────┴──────┴──────────┘

# %%
import polars as pl
import os

def merge_parquet_files(directory_path: str, output_file_path: str) -> None:
    """
    Merges multiple Parquet files located in a specified directory into a single Parquet file.

    Args:
    directory_path (str): The path to the directory containing the Parquet files.
    output_file_path (str): The path where the merged Parquet file will be saved.

    Returns:
    None
    """

    # List all Parquet files in the directory
    parquet_files = [file for file in os.listdir(directory_path) if file.endswith('.parquet')]

    # Read each Parquet file into a DataFrame and store in a list
    dataframes = [pl.read_parquet(os.path.join(directory_path, file)) for file in parquet_files]

    # Concatenate all DataFrames vertically
    merged_df = pl.concat(dataframes)

    # Write the merged DataFrame to a new Parquet file
    merged_df.write_parquet(output_file_path)

    print(f"Merged file saved to {output_file_path}")

# Specify the directory containing your Parquet files and the output file path
directory_path = '/workspace/soil-ml-modeling-pipeline/ml-modeling-pipeline/data/01_raw/eddi'
output_file_path = '/workspace/soil-ml-modeling-pipeline/ml-modeling-pipeline/data/01_raw/merged_eddi_data.parquet'

# Call the function to merge the files
merge_parquet_files(directory_path, output_file_path)
# Out:
# Merged file saved to /workspace/soil-ml-modeling-pipeline/ml-modeling-pipeline/data/01_raw/merged_eddi_data.parquet

# %%
# Define the path to your Parquet file
parquet_file_path = "/workspace/soil-ml-modeling-pipeline/ml-modeling-pipeline/data/01_raw/merged_eddi_data.parquet"

# Use Polars to read the Parquet file
df = pl.read_parquet(parquet_file_path)

# %%
df
# Out:
# shape: (62_374_360, 4)
# ┌─────────────────────┬───────┬──────┬───────────┐
# │ time                ┆ lat   ┆ lon  ┆ eddi      │
# │ ---                 ┆ ---   ┆ ---  ┆ ---       │
# │ datetime[μs]        ┆ f64   ┆ f64  ┆ f32       │
# ╞═════════════════════╪═══════╪══════╪═══════════╡
# │ 1981-01-01 00:00:00 ┆ 22.0  ┆ 23.0 ┆ -0.115403 │
# │ 1981-01-01 00:00:00 ┆ 22.0  ┆ 23.5 ┆ -0.057442 │
# │ 1981-01-01 00:00:00 ┆ 22.0  ┆ 24.0 ┆ -0.115403 │
# │ 1981-01-01 00:00:00 ┆ 22.0  ┆ 24.5 ┆ -0.17379  │
# │ 1981-01-01 00:00:00 ┆ 22.0  ┆ 25.0 ┆ -0.17379  │
# │ …                   ┆ …     ┆ …    ┆ …         │
# │ 2024-04-29 00:00:00 ┆ -11.5 ┆ 49.5 ┆ -999.0    │
# │ 2024-04-29 00:00:00 ┆ -11.5 ┆ 50.0 ┆ -999.0    │
# │ 2024-04-29 00:00:00 ┆ -11.5 ┆ 50.5 ┆ -999.0    │
# │ 2024-04-29 00:00:00 ┆ -11.5 ┆ 51.0 ┆ -999.0    │
# │ 2024-04-29 00:00:00 ┆ -11.5 ┆ 51.5 ┆ -999.0    │
# └─────────────────────┴───────┴──────┴───────────┘

# %%
df = df.sort(by="time")

# %%
df
# Out:
# shape: (62_374_360, 4)
# ┌─────────────────────┬───────┬──────┬───────────┐
# │ time                ┆ lat   ┆ lon  ┆ eddi      │
# │ ---                 ┆ ---   ┆ ---  ┆ ---       │
# │ datetime[μs]        ┆ f64   ┆ f64  ┆ f32       │
# ╞═════════════════════╪═══════╪══════╪═══════════╡
# │ 1981-01-01 00:00:00 ┆ 22.0  ┆ 23.0 ┆ -0.115403 │
# │ 1981-01-01 00:00:00 ┆ 22.0  ┆ 23.5 ┆ -0.057442 │
# │ 1981-01-01 00:00:00 ┆ 22.0  ┆ 24.0 ┆ -0.115403 │
# │ 1981-01-01 00:00:00 ┆ 22.0  ┆ 24.5 ┆ -0.17379  │
# │ 1981-01-01 00:00:00 ┆ 22.0  ┆ 25.0 ┆ -0.17379  │
# │ …                   ┆ …     ┆ …    ┆ …         │
# │ 2024-04-29 00:00:00 ┆ -11.5 ┆ 49.5 ┆ -999.0    │
# │ 2024-04-29 00:00:00 ┆ -11.5 ┆ 50.0 ┆ -999.0    │
# │ 2024-04-29 00:00:00 ┆ -11.5 ┆ 50.5 ┆ -999.0    │
# │ 2024-04-29 00:00:00 ┆ -11.5 ┆ 51.0 ┆ -999.0    │
# │ 2024-04-29 00:00:00 ┆ -11.5 ┆ 51.5 ┆ -999.0    │
# └─────────────────────┴───────┴──────┴───────────┘

# %%
output_file_path = '/workspace/soil-ml-modeling-pipeline/ml-modeling-pipeline/data/01_raw/merged_eddi_data.parquet'

# %%
df.write_parquet(output_file_path)

# %%
import polars as pl
import plotly.express as px

def visualize_eddi_map(df, specific_date):
    """
    Visualizes EDDI values on a map for a specific date, excluding missing data represented by -999.0.

    Parameters:
    - df (pl.DataFrame): The DataFrame containing time, latitude, longitude, and EDDI values.
    - specific_date (str): The specific date to visualize in "YYYY-MM-DD" format.

    Returns:
    - None: Displays an interactive map.
    """
    # Check and convert 'time' column to datetime if necessary
    # if df.schema()['time'] != pl.datatypes.Datetime:
    #     df = df.with_column(pl.col('time').str.strptime(pl.Datetime, format="%Y-%m-%d %H:%M:%S"))

    # Convert the specific date string to datetime object
    # specific_datetime = pl.datetime.strptime(specific_date + " 00:00:00", "%Y-%m-%d %H:%M:%S")

    # Filter the DataFrame for the specific date and exclude missing data
    date_filter = "1981-01-01"

    # Filter the DataFrame
    filtered_df = df.filter(pl.col("time").dt.date() == pl.lit(specific_date))

    # Convert Polars DataFrame to Pandas DataFrame for plotting
    pd_df = filtered_df.to_pandas()

    # Create a scatter map
    fig = px.scatter_geo(pd_df,
                         lat="lat",
                         lon="lon",
                         color="eddi",
                         hover_name="eddi",
                         projection="natural earth",
                         title=f"EDDI Visualization on Map for {specific_date}",
                         color_continuous_scale=px.colors.sequential.Plasma)
    
    # Update the layout to better fit the map presentation
    fig.update_layout(geo=dict(showland=True, landcolor="lightgrey"),
                      margin={"r":0,"t":50,"l":0,"b":0})

    fig.show()

# Example usage, ensure that 'df' is already your loaded DataFrame with proper columns
specific_date = "1981-01-08 00:00:00"
visualize_eddi_map(df, specific_date)
# Out:
# ---------------------------------------------------------------------------
# ComputeError                              Traceback (most recent call last)
# Cell In[19], line 46
#      44 # Example usage, ensure that 'df' is already your loaded DataFrame with proper columns
#      45 specific_date = "1981-01-08 00:00:00"
# ---> 46 visualize_eddi_map(df, specific_date)
#
# Cell In[19], line 23, in visualize_eddi_map(df, specific_date)
#       5 """
#       6 Visualizes EDDI values on a map for a specific date, excluding missing data represented by -999.0.
#       7
#    (...)
#      13 - None: Displays an interactive map.
#      14 """
#      15 # Check and convert 'time' column to datetime if necessary
#      16 # if df.schema()['time'] != pl.datatypes.Datetime:
#      17 #     df = df.with_column(pl.col('time').str.strptime(pl.Datetime, format="%Y-%m-%d %H:%M:%S"))
#    (...)
#      21
#      22 # Filter the DataFrame for the specific date and exclude missing data
# ---> 23 filtered_df = df.filter((pl.col("eddi") != -999.0) & (pl.col("time") == specific_date))
#      25 # Convert Polars DataFrame to Pandas DataFrame for plotting
#      26 pd_df = filtered_df.to_pandas()
#
# File /workspace/soil-ml-modeling-pipeline/.venv/lib/python3.11/site-packages/polars/dataframe/frame.py:3740, in DataFrame.filter(self, *predicates, **constraints)
#    3642 def filter(
#    3643     self,
#    3644     *predicates: (
#    (...)
#    3651     **constraints: Any,
#    3652 ) -> DataFrame:
#    3653     """
#    3654     Filter the rows in the DataFrame based on one or more predicate expressions.
#    3655
#    (...)
#    3738     └─────┴─────┴─────┘
#    3739     """
# -> 3740     return self.lazy().filter(*predicates, **constraints).collect(_eager=True)
#
# File /workspace/soil-ml-modeling-pipeline/.venv/lib/python3.11/site-packages/polars/lazyframe/frame.py:1708, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, no_optimization, streaming, background, _eager)
#    1705 if background:
#    1706     return InProcessQuery(ldf.collect_concurrently())
# -> 1708 return wrap_df(ldf.collect())
#
# ComputeError: cannot compare 'date/datetime/time' to a string value (create native python { 'date', 'datetime', 'time' } or compare to a temporal column)

# %%
def regrid_polars_df(df, start_lat=-12.0, start_lon=23.125, new_lat_res=0.5, new_lon_res=0.625):
    """
    Regrids a Polars DataFrame with latitude and longitude to a common specified grid, starting from specified latitude and longitude.

    Parameters:
    - df (pl.DataFrame): Polars DataFrame to be regridded.
    - start_lat (float): Starting latitude for the grid.
    - start_lon (float): Starting longitude for the grid.
    - new_lat_res (float): The new resolution for latitude.
    - new_lon_res (float): The new resolution for longitude.

    Returns:
    - pl.DataFrame: A DataFrame containing the regridded data.

    Example of usage:
    regridded_df = regrid_polars_df(polars_df)
    """
    # Calculate global min and max of latitude and longitude
    lat_min = df.select(pl.min('lat')).to_numpy().item()
    lat_max = df.select(pl.max('lat')).to_numpy().item()
    lon_min = df.select(pl.min('lon')).to_numpy().item()
    lon_max = df.select(pl.max('lon')).to_numpy().item()

    # Adjust the start points if they are outside the current data range
    start_lat = max(lat_min, start_lat)
    start_lon = max(lon_min, start_lon)

    # Create common latitude and longitude grids starting from the specified points
    common_lat = np.arange(start_lat, lat_max + new_lat_res, new_lat_res)
    common_lon = np.arange(start_lon, lon_max + new_lon_res, new_lon_res)

    # Function to find nearest grid point
    def find_nearest(array, value):
        idx = (np.abs(array - value)).argmin()
        return array[idx]

    # Map each lat and lon in the DataFrame to the nearest grid point
    df = df.with_columns([
        df['lat'].map_elements(lambda x: find_nearest(common_lat, x), return_dtype=float).alias('new_lat'),
        df['lon'].map_elements(lambda x: find_nearest(common_lon, x), return_dtype=float).alias('new_lon')
    ]).drop(['lat', 'lon']).rename({'new_lat': 'lat', 'new_lon': 'lon'})

    # Optional: Aggregate data if necessary
    df = df.group_by(['time', 'lat', 'lon']).agg(pl.col('eddi').mean().alias('eddi'))

    # Sort by time, latitude, and longitude for better organization
    df = df.sort(['time', 'lat', 'lon'])

    return df

# Usage example (assuming df is your DataFrame loaded with data)
regridded_df = regrid_polars_df(eddi_clean_df)

# %%
regridded_df
# Out:
# shape: (21_086_019, 4)
# ┌─────────────────────┬───────┬────────┬───────────┐
# │ time                ┆ lat   ┆ lon    ┆ eddi      │
# │ ---                 ┆ ---   ┆ ---    ┆ ---       │
# │ datetime[μs]        ┆ f64   ┆ f64    ┆ f32       │
# ╞═════════════════════╪═══════╪════════╪═══════════╡
# │ 2001-01-01 00:00:00 ┆ -12.0 ┆ 23.125 ┆ -0.761296 │
# │ 2001-01-01 00:00:00 ┆ -12.0 ┆ 23.75  ┆ -0.88392  │
# │ 2001-01-01 00:00:00 ┆ -12.0 ┆ 24.375 ┆ -0.926714 │
# │ 2001-01-01 00:00:00 ┆ -12.0 ┆ 25.0   ┆ -1.019687 │
# │ 2001-01-01 00:00:00 ┆ -12.0 ┆ 25.625 ┆ -1.019687 │
# │ …                   ┆ …     ┆ …      ┆ …         │
# │ 2024-04-13 00:00:00 ┆ 21.5  ┆ 38.75  ┆ 0.567209  │
# │ 2024-04-13 00:00:00 ┆ 21.5  ┆ 39.375 ┆ 0.437543  │
# │ 2024-04-13 00:00:00 ┆ 21.5  ┆ 40.0   ┆ 0.199132  │
# │ 2024-04-13 00:00:00 ┆ 21.5  ┆ 43.125 ┆ -0.500068 │
# │ 2024-04-13 00:00:00 ┆ 21.5  ┆ 48.75  ┆ -0.436921 │
# └─────────────────────┴───────┴────────┴───────────┘

# %%
regridded_df.write_parquet("/workspace/soil-ml-modeling-pipeline/ml-modeling-pipeline/data/01_raw/eddi.parquet")

# %% [markdown]
# # Helper functions for debugging

# %%
import requests

def download_file(url, destination_filename):
    """
    Download a file from a specified URL and save it locally.

    Parameters:
    - url (str): URL of the file to download.
    - destination_filename (str): Name of the file to save the downloaded content.

    Returns:
    - None
    """
    # Send a GET request to the URL
    response = requests.get(url)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Write the content of the response to a file
        with open(destination_filename, 'wb') as f:
            f.write(response.content)
        print("File downloaded successfully!")
    else:
        print(f"Failed to download the file. Status code: {response.status_code}")

# URL of the file to be downloaded
file_url = "https://downloads.psl.noaa.gov/Projects/EDDI/global_archive/NCEP/2002/EDDI_06mn_20020612.asc"

# Name of the file to save locally
local_filename = "/workspace/soil-ml-modeling-pipeline/ml-modeling-pipeline/data/01_raw/EDDI_12mn_20020612.asc"

# Call the function to download the file
download_file(file_url, local_filename)

# %%
import rasterio
from rasterio.transform import from_origin

def load_ascii_grid(file_path: str):
    """
    Load an ASCII grid file using rasterio and return its data along with metadata.

    This function opens the specified ASCII grid file, reads its contents,
    and returns both the grid data as a numpy ndarray and the metadata profile
    associated with the raster dataset.

    Parameters:
    - file_path (str): The file path to the ASCII grid file.

    Returns:
    - tuple:
        - data (numpy.ndarray): The raster data read from the file.
        - profile (dict): The metadata profile of the raster dataset, which includes
          details about the data format, dimensions, and georeferencing.

    Raises:
    - FileNotFoundError: If the file does not exist at the specified path.
    - rasterio.errors.RasterioIOError: If there is an error opening the file with rasterio.
    """

    with rasterio.open(file_path, mode='r') as src:
        data = src.read(1)  # Read the first and only band
        profile = src.profile

    return data, profile

# Example usage
file_path = '/workspace/soil-ml-modeling-pipeline/ml-modeling-pipeline/data/01_raw/EDDI_12mn_20020612.asc'
try:
    data, profile = load_ascii_grid(file_path)
    print("Data loaded successfully.")
    print("Raster profile:", profile)
except Exception as e:
    print("An error occurred:", e)

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_raster(data, nodata_value, title="Raster Data Visualization"):
    """
    Plots the raster data using matplotlib, masking the 'nodata' values.

    Parameters:
    - data (numpy.ndarray): The raster data to plot.
    - nodata_value (float): The value that indicates no data in the raster.
    - title (str): The title of the plot.
    """
    # Mask the no-data values
    data_masked = np.ma.masked_where(data == nodata_value, data)

    plt.figure(figsize=(12, 6))
    plt.imshow(data_masked, cmap='viridis', interpolation='nearest')
    plt.colorbar(label='Data values')
    plt.title(title)
    plt.xlabel('Longitude Index')
    plt.ylabel('Latitude Index')
    plt.show()

# Example usage
plot_raster(data, -999.0)

# %%
from rasterio.transform import Affine
import numpy as np

def geographic_to_index(lon, lat, transform):
    """
    Convert geographic coordinates to raster indices.

    Parameters:
    - lon (float): The longitude to convert.
    - lat (float): The latitude to convert.
    - transform (Affine): The affine transform associated with the raster, defining how geographic coordinates are transformed into raster indices.

    Returns:
    - (int, int): The zero-based column index and row index corresponding to the given longitude and latitude.
    """
    col, row = ~transform * (lon, lat)
    return int(col), int(row)

def filter_raster_data(data, row_start, row_end, col_start, col_end):
    """
    Filter the raster data array to include only the data within specified index ranges.

    Parameters:
    - data (numpy.ndarray): The full raster data array.
    - row_start (int): The starting index for rows.
    - row_end (int): The ending index for rows.
    - col_start (int): The starting index for columns.
    - col_end (int): The ending index for columns.

    Returns:
    - numpy.ndarray: The filtered raster data array.
    """
    return data[row_start:row_end, col_start:col_end]

# Define the affine transform for a raster where each pixel represents a 0.5x0.5 degree area
transform = Affine(0.5, 0.0, -180, 0.0, -0.5, 90)

# Define geographic bounds and calculate index ranges
lat_range = (-12, 22)  # South to North
lon_range = (23, 52)  # West to East
col_start, row_end = geographic_to_index(lon_range[0], lat_range[0], transform)
col_end, row_start = geographic_to_index(lon_range[1], lat_range[1], transform)

# Assuming 'data' is your loaded raster data
filtered_data = filter_raster_data(data, row_start, row_end, col_start, col_end)
print(filtered_data)
